# %% [markdown]
# # ROGII Wellbore: DWT artifact ensemble, validation, and fork guide
#
# This notebook is a forkable walkthrough of the strongest route I have
# locally scored on the `afr1ste` account so far: a true runnable fork of
# the DWT/artifact ensemble route. The scored submission was:
#
# | Item | Value |
# | --- | --- |
# | Local account submission ref | `52668897` |
# | Public RMSE | `9.674` |
# | Kernel route | `afr1ste/rogii-adarsh-dwt-dump-fork` v1 |
# | Output contract | `submission.csv` with `14151` rows, `id,tvt`, sample order |
#
# The goal of this public version is not just to emit a CSV. It shows how
# to make a code-competition notebook reproducible: clean inputs, stable
# paths, cached artifact loading, strict validation, and safe submission.

# %% [markdown]
# ## Score honesty
#
# A separate machine/account shared a stronger THBDH v10 fresh-artifact
# route at public RMSE `9.508`. I treat that as an important route lesson,
# not as a locally verified score for this account. On `afr1ste`, the
# best scored row remains `9.674` from this DWT artifact route.
#
# The practical lesson is still the same: the best public ROGII notebooks
# are usually true runnable forks with accessible artifacts. Public-output
# bridges can validate locally but may return blank public scores in this
# code competition.

# %% [markdown]
# ## What the pipeline does
#
# The notebook follows this high-level flow:
#
# 1. Discover the competition and artifact input paths robustly.
# 2. Load or build train/test feature tables for horizontal wells.
# 3. Reuse cached LightGBM/CatBoost artifacts when available.
# 4. Blend model predictions with hill climbing and a small postprocess.
# 5. Write `/kaggle/working/submission.csv`.
# 6. Validate the output shape, id order, and finite `tvt` values.
#
# If you fork this, keep the validation cell. It catches the most common
# costly mistakes before you spend a daily submission slot.

# %% [markdown]
# ## Forking checklist
#
# For Kaggle code competitions, submit the kernel output, not a local CSV:
#
# ```bash
# kaggle competitions submit rogii-wellbore-geology-prediction \
#   -k <your-user>/<your-kernel> -v <completed-version> \
#   -f submission.csv -m "clear candidate message"
# ```
#
# Before pushing your own fork:
#
# - remove inherited `id_no` and pinned `docker_image` metadata;
# - keep only public/addable dataset sources;
# - use a single GPU device such as `devices="0"` if you run CatBoost on T4;
# - write UTF-8 without BOM;
# - validate `submission.csv` against `sample_submission.csv`;
# - compare against your pinned best so you do not submit a duplicate.

# %% [markdown]
# # 1. Imports and configs

# %%
from sklearn.metrics import root_mean_squared_error
from sklearn.model_selection import GroupKFold
from sklearn.linear_model import Ridge
from catboost import CatBoostRegressor, Pool
from scipy.spatial import cKDTree
from scipy.signal import savgol_filter
from joblib import Parallel, delayed
from pathlib import Path
from numba import njit, prange
import matplotlib.pyplot as plt
import lightgbm as lgb
import multiprocessing
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
import joblib
import optuna
import time
import os
 
warnings.filterwarnings("ignore")

# === INLINE Climber replacement (was: from hill_climbing import Climber) ===
# Replaces the hill-climbing PyPI Climber with a constrained NNLS / hill-climbing
# implementation. Same public API: .fit(oof_preds_df, y) and .predict(df), .best_score
class Climber:
    def __init__(self, objective='minimize', eval_metric=None, allow_negative_weights=False,
                 precision=0.001, score_decimal_places=3, n_jobs=-1, use_gpu=False):
        self.objective = objective
        self.eval_metric = eval_metric or (lambda yt, yp: float(np.sqrt(np.mean((yt - yp) ** 2))))
        self.allow_negative_weights = allow_negative_weights
        self.precision = precision
        self.score_decimal_places = score_decimal_places
        self.weights_ = None
        self.cols_ = None
        self.best_score = None
    def fit(self, oof_df, y):
        import numpy as _np
        self.cols_ = list(oof_df.columns)
        P = oof_df.values.astype(_np.float64)
        y_arr = _np.asarray(y, dtype=_np.float64)
        M = P.shape[1]
        # init: pick single best model
        single_scores = [self.eval_metric(y_arr, P[:, i]) for i in range(M)]
        best_i = int(_np.argmin(single_scores))
        w = _np.zeros(M, dtype=_np.float64); w[best_i] = 1.0
        cur_pred = P @ w
        cur_score = self.eval_metric(y_arr, cur_pred)
        step = max(self.precision, 1e-4)
        # hill climb: at each round, try moving precision from one weight to another
        improved = True
        rounds = 0
        while improved and rounds < 2000:
            improved = False
            rounds += 1
            best_delta = 0.0
            best_move = None
            best_pred = cur_pred
            for src in range(M):
                if w[src] < step - 1e-12:
                    continue
                delta_p_src = -step * P[:, src]
                for dst in range(M):
                    if dst == src: continue
                    if (not self.allow_negative_weights) and (w[dst] + step > 1 + 1e-12):
                        continue
                    new_pred = cur_pred + delta_p_src + step * P[:, dst]
                    new_score = self.eval_metric(y_arr, new_pred)
                    delta = cur_score - new_score
                    if delta > best_delta + 1e-9:
                        best_delta = delta
                        best_move = (src, dst)
                        best_pred = new_pred
            if best_move is not None:
                src, dst = best_move
                w[src] -= step; w[dst] += step
                cur_pred = best_pred
                cur_score = self.eval_metric(y_arr, cur_pred)
                improved = True
        self.weights_ = w
        self.best_score = float(cur_score)
        return self
    def predict(self, df):
        import numpy as _np
        P = df[self.cols_].values.astype(_np.float64)
        return P @ self.weights_
# === END inline Climber ===

# %%
from pathlib import Path as _P
def _find_dataset(slug, owner=None):
    candidates = [
        _P(f"/kaggle/input/datasets/{owner}/{slug}") if owner else None,
        _P(f"/kaggle/input/{slug}"),
        _P(f"/kaggle/input/{owner}/{slug}") if owner else None,
    ]
    for c in candidates:
        if c is not None and c.exists():
            return c
    # Final fallback: scan
    inp = _P("/kaggle/input")
    if inp.exists():
        for sub in inp.iterdir():
            if slug in sub.name:
                return sub
    return _P(f"/kaggle/input/{slug}")  # last resort, may not exist

def _find_competition(slug):
    candidates = [_P(f"/kaggle/input/competitions/{slug}"), _P(f"/kaggle/input/{slug}")]
    for c in candidates:
        if c.exists():
            return c
    return _P(f"/kaggle/input/competitions/{slug}")


class CFG:
    dataset_path = _find_competition("rogii-wellbore-geology-prediction")
    artifacts_path = _find_dataset("wellbore-geology-prediction-artifacts", owner="ravaghi")
    seed = 42
    n_splits = 5
    cv = GroupKFold(n_splits=n_splits)
    metric = root_mean_squared_error

print(f"[CFG] dataset_path = {CFG.dataset_path} exists={CFG.dataset_path.exists()}")
print(f"[CFG] artifacts_path = {CFG.artifacts_path} exists={CFG.artifacts_path.exists()}")
if CFG.artifacts_path.exists():
    print(f"[CFG] artifacts contents:")
    for p in sorted(CFG.artifacts_path.glob('*'))[:10]:
        print(f'   {p.name}')
    train_csv = CFG.artifacts_path / 'data' / 'train.csv'
    print(f"[CFG] artifacts/data/train.csv exists: {train_csv.exists()}")
# Out:
# [CFG] dataset_path = /kaggle/input/competitions/rogii-wellbore-geology-prediction exists=True
# [CFG] artifacts_path = /kaggle/input/datasets/ravaghi/wellbore-geology-prediction-artifacts exists=True
# [CFG] artifacts contents:
#    data
#    models
# [CFG] artifacts/data/train.csv exists: True

# %% [markdown]
# # 2. Data loading and preprocessing

# %%
SEED = 42; np.random.seed(SEED)
NCPU = min(4, multiprocessing.cpu_count())
 
FORMATIONS = ["ANCC", "ASTNU", "ASTNL", "EGFDU", "EGFDL", "BUDA"]
PLANE_K = 10; DENSE_SPW = 60; DENSE_K = 20; N_SPLITS = 5
 
BEAMS = [
    (10, 20.0, 144.0, 2, "cons"),
    (10,  8.0,  64.0, 2, "loose"),
    ( 8, 35.0, 220.0, 1, "vcons"),
    (10, 14.0,  90.0, 5, "sm5"),
    (20,  4.0,  36.0, 3, "vloose"),
    (12, 12.0, 100.0, 3, "mid"),
    (15, 25.0, 180.0, 2, "stiff"),
]
 
PF_N = 600; ANCC_N = 600
PF_MOM = 0.993; PF_VN = 0.005; PF_PN = 0.01
PF_GR_SIG_MIN = 10.; PF_GR_SIG_MAX = 60.; PF_GR_SIG_DEF = 30.
PF_INIT_V_STD = 0.02; PF_INIT_SPR = 0.5; PF_RESAMP = 0.5
PF_ROUGH_P = 0.2; PF_ROUGH_V = 0.003; PF_GR_WIN = 5; PF_GR_WT = 0.3
ANCC_ALPHA = 0.998; ANCC_RN = 0.002; ANCC_PN = 0.005
ANCC_IR = 0.01; ANCC_IS = 0.3; ANCC_RP = 0.1; ANCC_RR = 0.001
 
DTW_RADII = (20, 50, 100, 200)
DTW_STOCH_K = 12
DTW_STOCH_TEMP = 3.0
 
 
@njit(cache=True)
def _interp1(grid, v, vmin, step):
    i = int((v - vmin) / step)
    if i < 0: return grid[0]
    n = len(grid) - 1
    if i >= n: return grid[n]
    t = (v - vmin) / step - i
    return grid[i] * (1. - t) + grid[i + 1] * t
 
 
@njit(cache=True)
def _resamp(pos, aux, w, N, rp, rv):
    cum = np.zeros(N + 1)
    for j in range(N): cum[j + 1] = cum[j] + w[j]
    u0 = np.random.uniform(0., 1. / N)
    np2 = np.empty(N); na = np.empty(N); ci = 0
    for j in range(N):
        u = u0 + j / N
        while ci < N - 1 and cum[ci + 1] < u: ci += 1
        np2[j] = pos[ci] + rp * np.random.randn()
        na[j] = aux[ci] + rv * np.random.randn()
    return np2, na
 
 
@njit(cache=True)
def _beam_jit(sgr, tw_gr, si, BS, mc, es):
    n = len(sgr); nt = len(tw_gr); MAX = BS * 6
    bidx = np.zeros(BS, np.int64); bidx[0] = si
    bcost = np.full(BS, 1e30);     bcost[0] = 0.; bn = np.int64(1)
    hI = np.zeros((n, BS), np.int64); hP = np.zeros((n, BS), np.int64)
    cI = np.zeros(MAX, np.int64); cC = np.full(MAX, 1e30); cP = np.zeros(MAX, np.int64)
    for step in range(n):
        gv = sgr[step]; nc = np.int64(0)
        for bi in range(bn):
            idx = bidx[bi]; cost = bcost[bi]
            for d in range(-2, 3):
                ni = idx + d
                if ni < 0 or ni >= nt: continue
                tot = cost + (gv - tw_gr[ni]) ** 2 / es + mc * (d if d >= 0 else -d)
                fnd = np.int64(-1)
                for ci in range(nc):
                    if cI[ci] == ni: fnd = ci; break
                if fnd >= 0:
                    if tot < cC[fnd]: cC[fnd] = tot; cP[fnd] = bi
                else:
                    if nc < MAX: cI[nc] = ni; cC[nc] = tot; cP[nc] = bi; nc += 1
        kept = min(BS, nc)
        for i in range(kept):
            mi = i
            for j in range(i + 1, nc):
                if cC[j] < cC[mi]: mi = j
            if mi != i:
                cI[i], cI[mi] = cI[mi], cI[i]
                cC[i], cC[mi] = cC[mi], cC[i]
                cP[i], cP[mi] = cP[mi], cP[i]
        hI[step, :kept] = cI[:kept]; hP[step, :kept] = cP[:kept]
        bidx[:kept] = cI[:kept]; bcost[:kept] = cC[:kept]; bn = kept
    best = np.int64(0)
    for b in range(1, bn):
        if bcost[b] < bcost[best]: best = b
    path = np.zeros(n, np.int64); b = best
    for s in range(n - 1, -1, -1): path[s] = hI[s, b]; b = hP[s, b]
    return path
 
 
@njit(cache=True)
def _dtw_sakoe_chiba(query, ref, radius):
    """
    Constrained DTW with Sakoe-Chiba band.
    Returns (cost_matrix, accumulated_cost_matrix, path_i, path_j).
    Uses slanted band: diagonal from (0,0) to (N-1,M-1).
    """
    N = len(query); M = len(ref)
    INF = 1e18
    D = np.full((N, M), INF)
 
    slope = (M - 1.0) / max(N - 1.0, 1.0)
    for i in range(N):
        j_center = int(round(i * slope))
        j_lo = max(0, j_center - radius)
        j_hi = min(M - 1, j_center + radius)
        for j in range(j_lo, j_hi + 1):
            cost = (query[i] - ref[j]) ** 2
            if i == 0 and j == 0:
                D[i, j] = cost
            elif i == 0:
                prev = D[i, j - 1]
                D[i, j] = cost + (prev if prev < INF else INF)
            elif j == 0:
                prev = D[i - 1, j]
                D[i, j] = cost + (prev if prev < INF else INF)
            else:
                a = D[i - 1, j - 1]
                b = D[i - 1, j]
                c = D[i, j - 1]
                mn = a if a < b else b
                mn = mn if mn < c else c
                D[i, j] = cost + (mn if mn < INF else INF)
 
    i = N - 1; j = M - 1
    pi = np.zeros(N + M, np.int64)
    pj = np.zeros(N + M, np.int64)
    k = 0
    while i > 0 or j > 0:
        pi[k] = i; pj[k] = j; k += 1
        if i == 0:
            j -= 1
        elif j == 0:
            i -= 1
        else:
            a = D[i - 1, j - 1]; b = D[i - 1, j]; c = D[i, j - 1]
            if a <= b and a <= c:
                i -= 1; j -= 1
            elif b <= c:
                i -= 1
            else:
                j -= 1
    pi[k] = 0; pj[k] = 0; k += 1
    return D, pi[:k], pj[:k]
 
 
@njit(cache=True)
def _dtw_path_to_tvt(pi, pj, tw_tvt, N):
    """
    Convert DTW warping path to per-query-sample TVT estimate.
    For each query index i, find the corresponding typewell index j,
    then look up tw_tvt[j].
    """
    j_for_i = np.zeros(N, np.int64)
    for k in range(len(pi)):
        j_for_i[pi[k]] = pj[k]
    result = np.empty(N, np.float32)
    for i in range(N):
        result[i] = tw_tvt[j_for_i[i]]
    return result
 
 
@njit(cache=True)
def _dtw_path_slope(pi, pj, N, smooth_win=5):
    """
    Compute local slope dj/di along the warping path — encodes TVT rate.
    """
    j_for_i = np.zeros(N, np.float64)
    for k in range(len(pi)):
        j_for_i[pi[k]] = float(pj[k])
 
    slope = np.zeros(N, np.float32)
    hw = smooth_win // 2
    for i in range(N):
        i0 = max(0, i - hw); i1 = min(N - 1, i + hw)
        if i1 > i0:
            slope[i] = float((j_for_i[i1] - j_for_i[i0]) / (i1 - i0))
        else:
            slope[i] = 1.0
    return slope
 
 
@njit(cache=True)
def _dtw_stochastic_realizations(query, ref, radius, K, temperature):
    """
    Stochastic DTW: sample K realizations of the warping path by adding
    Gumbel noise to the cost matrix before traceback.
    Returns (K, N) array of typewell indices per realization.
    """
    N = len(query); M = len(ref)
    INF = 1e18
    slope = (M - 1.0) / max(N - 1.0, 1.0)
 
    D_base = np.full((N, M), INF)
    for i in range(N):
        j_center = int(round(i * slope))
        j_lo = max(0, j_center - radius)
        j_hi = min(M - 1, j_center + radius)
        for j in range(j_lo, j_hi + 1):
            D_base[i, j] = (query[i] - ref[j]) ** 2
 
    paths = np.zeros((K, N), np.int64)
    for k in range(K):
        D = np.full((N, M), INF)
        for i in range(N):
            j_center = int(round(i * slope))
            j_lo = max(0, j_center - radius)
            j_hi = min(M - 1, j_center + radius)
            for j in range(j_lo, j_hi + 1):
                noise = -temperature * np.log(-np.log(np.random.uniform(1e-10, 1.0)))
                cost = D_base[i, j] + noise
                if i == 0 and j == 0:
                    D[i, j] = cost
                elif i == 0:
                    prev = D[i, j - 1]
                    D[i, j] = cost + (prev if prev < INF else INF)
                elif j == 0:
                    prev = D[i - 1, j]
                    D[i, j] = cost + (prev if prev < INF else INF)
                else:
                    a = D[i - 1, j - 1]; b = D[i - 1, j]; c = D[i, j - 1]
                    mn = a if a < b else b
                    mn = mn if mn < c else c
                    D[i, j] = cost + (mn if mn < INF else INF)
 
        i = N - 1; j = M - 1
        j_for_i = np.zeros(N, np.int64)
        while i > 0 or j > 0:
            j_for_i[i] = j
            if i == 0:
                j -= 1
            elif j == 0:
                i -= 1
            else:
                a = D[i - 1, j - 1]; b = D[i - 1, j]; c = D[i, j - 1]
                if a <= b and a <= c:
                    i -= 1; j -= 1
                elif b <= c:
                    i -= 1
                else:
                    j -= 1
        j_for_i[0] = j
        paths[k] = j_for_i
 
    return paths
 
 
@njit(cache=True)
def _pf_ancc(md_v, z_v, gr_v, gg, vmin, step, gs, ls, ir, N,
             ALPHA, RN, PN, IS, RP, RR, RESAMP):
    pos = np.empty(N); rate = np.empty(N); w = np.ones(N) / N
    for j in range(N):
        pos[j] = ls + IS * np.random.randn()
        rate[j] = ir + 0.01 * np.random.randn()
    pts = np.empty(len(md_v)); std_ = np.empty(len(md_v)); pm = md_v[0] - 1.
    for i in range(len(md_v)):
        dm = md_v[i] - pm; dm = max(dm, 1.)
        for j in range(N):
            rate[j] = ALPHA * rate[j] + RN * np.random.randn()
            pos[j] += rate[j] * dm + PN * np.random.randn()
            tvt_j = pos[j] - z_v[i]
            tvt_j = max(tvt_j, vmin - 50.); tvt_j = min(tvt_j, vmin + len(gg) * step + 50.)
            pos[j] = tvt_j + z_v[i]
        if not np.isnan(gr_v[i]):
            ws = 0.
            for j in range(N):
                eg = _interp1(gg, pos[j] - z_v[i], vmin, step)
                d = (gr_v[i] - eg) / gs
                lk = max(np.exp(-0.5 * d * d) if d * d < 600. else 0., 1e-300)
                w[j] *= lk; ws += w[j]
            if ws > 0.:
                for j in range(N): w[j] /= ws
            else:
                for j in range(N): w[j] = 1. / N
        ne = 0.
        for j in range(N): ne += w[j] * w[j]
        if 1. / ne < RESAMP * N:
            pos, rate = _resamp(pos, rate, w, N, RP, RR)
            for j in range(N): w[j] = 1. / N
        tv = 0.
        for j in range(N): tv += w[j] * (pos[j] - z_v[i])
        pts[i] = tv; va = 0.
        for j in range(N): va += w[j] * (pos[j] - z_v[i] - tv) ** 2
        std_[i] = va ** 0.5; pm = md_v[i]
    return pts, std_
 
 
@njit(cache=True)
def _pf_z(md_v, z_v, gr_v, gr_sm_v, gg_p, gg_s, vmin, step,
          gs, ip, iv, beta, icpt, zsig, N,
          MOM, VN, PN, GR_WT, RP, RV, RESAMP):
    pos = np.empty(N); vel = np.empty(N); w = np.ones(N) / N
    for j in range(N):
        pos[j] = ip + 0.5 * np.random.randn()
        vel[j] = iv + 0.02 * np.random.randn()
    pts = np.empty(len(md_v)); std_ = np.empty(len(md_v)); pm = md_v[0] - 1.; pz = z_v[0] - 1.
    for i in range(len(md_v)):
        dm = md_v[i] - pm; dm = max(dm, 1.)
        dzd = (z_v[i] - pz) / dm; ve = beta * dzd + icpt
        for j in range(N):
            vel[j] = MOM * vel[j] + VN * np.random.randn()
            pos[j] += vel[j] * dm + PN * np.random.randn()
            pos[j] = max(pos[j], vmin - 50.); pos[j] = min(pos[j], vmin + len(gg_p) * step + 50.)
        if not np.isnan(gr_v[i]):
            ws = 0.
            for j in range(N):
                ep = _interp1(gg_p, pos[j], vmin, step)
                dp = (gr_v[i] - ep) / gs
                lp = max(np.exp(-0.5 * dp * dp) if dp * dp < 600. else 0., 1e-300)
                if not np.isnan(gr_sm_v[i]):
                    es = _interp1(gg_s, pos[j], vmin, step)
                    ds = (gr_sm_v[i] - es) / (gs * 1.5)
                    ls = max(np.exp(-0.5 * ds * ds) if ds * ds < 600. else 0., 1e-300)
                    lk = (1. - GR_WT) * lp + GR_WT * ls
                else:
                    lk = lp
                lk = max(lk, 1e-300); w[j] *= lk; ws += w[j]
            if ws > 0.:
                for j in range(N): w[j] /= ws
            else:
                for j in range(N): w[j] = 1. / N
        ws2 = 0.
        for j in range(N):
            dv = (vel[j] - ve) / max(zsig * 2., 0.005)
            lz = max(np.exp(-0.5 * dv * dv) if dv * dv < 600. else 0., 1e-300)
            w[j] *= lz; ws2 += w[j]
        if ws2 > 0.:
            for j in range(N): w[j] /= ws2
        else:
            for j in range(N): w[j] = 1. / N
        ne = 0.
        for j in range(N): ne += w[j] * w[j]
        if 1. / ne < RESAMP * N:
            pos, vel = _resamp(pos, vel, w, N, RP, RV)
            for j in range(N): w[j] = 1. / N
        wm = 0.
        for j in range(N): wm += w[j] * pos[j]
        pts[i] = wm; va = 0.
        for j in range(N): va += w[j] * (pos[j] - wm) ** 2
        std_[i] = va ** 0.5; pm = md_v[i]; pz = z_v[i]
    return pts, std_
 
 
def _grid(tw_tvt, tw_gr, step=0.2):
    tmin = float(tw_tvt.min()); tmax = float(tw_tvt.max())
    tvt_g = np.arange(tmin, tmax + step, step)
    return np.interp(tvt_g, tw_tvt, tw_gr).astype(np.float64), float(tmin), float(step)
 
 
def _gr_sig(hw, tw_tvt, tw_gr):
    kn = hw[hw['TVT_input'].notna() & hw['GR'].notna()]
    if len(kn) < 20: return float(PF_GR_SIG_DEF)
    return float(np.clip(np.std(kn['GR'].values - np.interp(kn['TVT_input'].values, tw_tvt, tw_gr)),
                         PF_GR_SIG_MIN, PF_GR_SIG_MAX))
 
 
def _nn(arr, v):
    i = int(np.searchsorted(arr, v, 'left'))
    if i >= len(arr): return len(arr) - 1
    if i > 0 and abs(arr[i - 1] - v) <= abs(arr[i] - v): return i - 1
    return i
 
 
def _smooth(vals, fb, r):
    s = pd.Series(vals, dtype='float32').interpolate(limit_direction='both').fillna(fb)
    return (s.rolling(r * 2 + 1, center=True, min_periods=1).mean() if r > 0 else s).to_numpy(np.float32)
 
 
def beam_search(gr_h, tw_tvt, tw_gr, start_tvt, bs, mc, es, r):
    si = _nn(tw_tvt, start_tvt)
    sgr = _smooth(gr_h, float(np.nanmean(tw_gr)), r).astype(np.float64)
    path = _beam_jit(sgr, tw_gr.astype(np.float64), si, bs, float(mc), float(es))
    return tw_tvt[path].astype(np.float32)
 
 
def run_pf_ancc(hw, tw_tvt, tw_gr, N=ANCC_N):
    gs = _gr_sig(hw, tw_tvt, tw_gr)
    kn = hw[hw['TVT_input'].notna()]; ev = hw[hw['TVT_input'].isna()]
    if len(ev) == 0: return np.array([]), np.array([])
    ls = float(kn['TVT_input'].iloc[-1] + kn['Z'].iloc[-1])
    tail = kn.tail(30); dt = np.diff(tail['TVT_input'].values)
    dz = np.diff(tail['Z'].values); dm = np.diff(tail['MD'].values); m = dm > 0
    ir = float(np.median((dt + dz)[m] / dm[m])) if m.sum() >= 3 else 0.
    gg, gmin, gst = _grid(tw_tvt, tw_gr)
    pts, std = _pf_ancc(ev['MD'].values.astype(np.float64), ev['Z'].values.astype(np.float64),
                        ev['GR'].values.astype(np.float64), gg, gmin, gst,
                        gs, ls, ir, N, ANCC_ALPHA, ANCC_RN, ANCC_PN, ANCC_IS, ANCC_RP, ANCC_RR, PF_RESAMP)
    return pts.astype(np.float32), std.astype(np.float32)
 
 
def run_pf_z(hw, tw_tvt, tw_gr, N=PF_N):
    gs = _gr_sig(hw, tw_tvt, tw_gr)
    tw_s = pd.Series(tw_gr).rolling(PF_GR_WIN, center=True, min_periods=1).mean().values.astype(np.float32)
    kna = hw[hw['TVT_input'].notna()]; ev = hw[hw['TVT_input'].isna()]
    if len(ev) == 0: return np.array([]), np.array([])
    dz_k = np.diff(kna['Z'].values); dvt = np.diff(kna['TVT_input'].values)
    dmd_k = np.diff(kna['MD'].values); m2 = dmd_k > 0
    if m2.sum() >= 10:
        vz = dz_k[m2] / dmd_k[m2]; vt = dvt[m2] / dmd_k[m2]
        A = np.column_stack([vz, np.ones_like(vz)]); c, _, _, _ = np.linalg.lstsq(A, vt, rcond=None)
        beta, icpt, zsig = float(c[0]), float(c[1]), max(float(np.std(vt - (c[0] * vz + c[1]))), 0.001)
    else:
        beta, icpt, zsig = -1., 0., 0.1
    t2 = kna.tail(20); dvt2 = np.diff(t2['TVT_input'].values); dmd2 = np.diff(t2['MD'].values); m3 = dmd2 > 0
    iv = float(np.median(dvt2[m3] / dmd2[m3])) if m3.sum() >= 3 else 0.
    gg, gmin, gst = _grid(tw_tvt, tw_gr)
    gs2, _, _ = _grid(tw_tvt, tw_s)
    gr_sm = hw['GR'].rolling(PF_GR_WIN, center=True, min_periods=1).mean()
    pts, std = _pf_z(ev['MD'].values.astype(np.float64), ev['Z'].values.astype(np.float64),
                     ev['GR'].values.astype(np.float64),
                     gr_sm.loc[ev.index].values.astype(np.float64),
                     gg, gs2, gmin, gst, gs, float(kna['TVT_input'].iloc[-1]), iv,
                     beta, icpt, zsig, N,
                     PF_MOM, PF_VN, PF_PN, PF_GR_WT, PF_ROUGH_P, PF_ROUGH_V, PF_RESAMP)
    return pts.astype(np.float32), std.astype(np.float32)
 
 
def run_dtw_multiscale(query_gr, tw_tvt, tw_gr, last_tvt, radii=DTW_RADII):
    """
    Multi-scale constrained DTW alignment of horizontal-well GR to typewell GR.
    For each Sakoe-Chiba radius, runs DTW and maps the warping path back to TVT space.
 
    Returns:
        dtw_tvts    : dict radius -> (N,) float32 TVT predictions
        dtw_slopes  : dict radius -> (N,) float32 local path slopes
        dtw_costs   : dict radius -> float  normalised alignment cost
        dtw_ens     : (N,) float32 cost-weighted ensemble TVT
    """
    N = len(query_gr)
    qn = (query_gr - query_gr.mean()) / (query_gr.std() + 1e-6)
    rn = (tw_gr - tw_gr.mean()) / (tw_gr.std() + 1e-6)
 
    si = _nn(tw_tvt, last_tvt)
    qn_f = qn.astype(np.float64)
    rn_f = rn.astype(np.float64)
 
    dtw_tvts = {}; dtw_slopes = {}; dtw_costs = {}
    inv_cost_sum = 0.0
    tvt_stack = []
 
    for r in radii:
        D, pi, pj = _dtw_sakoe_chiba(qn_f, rn_f, r)
        cost = float(D[len(qn_f) - 1, len(rn_f) - 1]) / max(len(qn_f) + len(rn_f), 1)
        tvt_pred = _dtw_path_to_tvt(pi[::-1], pj[::-1], tw_tvt.astype(np.float32), N)
        slope = _dtw_path_slope(pi[::-1], pj[::-1], N)
        dtw_tvts[r] = tvt_pred
        dtw_slopes[r] = slope
        dtw_costs[r] = cost
        ic = 1.0 / (cost + 1e-6)
        inv_cost_sum += ic
        tvt_stack.append((tvt_pred, ic))
 
    weights = np.array([ic / inv_cost_sum for _, ic in tvt_stack], dtype=np.float32)
    tvts_mat = np.stack([t for t, _ in tvt_stack], axis=1)
    dtw_ens = (tvts_mat * weights[None, :]).sum(axis=1).astype(np.float32)
 
    return dtw_tvts, dtw_slopes, dtw_costs, dtw_ens
 
 
def run_dtw_stochastic(query_gr, tw_tvt, tw_gr, last_tvt,
                       radius=50, K=DTW_STOCH_K, temperature=DTW_STOCH_TEMP):
    """
    Stochastic DTW: K noisy traceback realizations to quantify uncertainty.
    Returns (mean_tvt, std_tvt, cv_tvt) all (N,) float32.
    """
    N = len(query_gr)
    qn = ((query_gr - query_gr.mean()) / (query_gr.std() + 1e-6)).astype(np.float64)
    rn = ((tw_gr - tw_gr.mean()) / (tw_gr.std() + 1e-6)).astype(np.float64)
 
    paths = _dtw_stochastic_realizations(qn, rn, radius, K, temperature)
    tvt_realiz = np.empty((K, N), dtype=np.float32)
    for k in range(K):
        for i in range(N):
            tvt_realiz[k, i] = tw_tvt[paths[k, i]]
 
    mean_tvt = tvt_realiz.mean(axis=0).astype(np.float32)
    std_tvt = tvt_realiz.std(axis=0).astype(np.float32)
    cv_tvt = (std_tvt / (np.abs(mean_tvt) + 1e-6)).astype(np.float32)
    return mean_tvt, std_tvt, cv_tvt
 
 
_md = np.linspace(1, 50, 20, np.float64); _z = np.zeros(20, np.float64); _gr = np.full(20, 50., np.float64)
_gg = np.linspace(45, 55, 100, np.float64)
_pf_ancc(_md, _z, _gr, _gg, 45., 0.1, 20., 50., 0., 8, 0.998, 0.002, 0.005, 0.3, 0.1, 0.001, 0.5)
_pf_z(_md, _z, _gr, _gr, _gg, _gg, 45., 0.1, 20., 50., 0., -1., 0., 0.1, 8, 0.993, 0.005, 0.01, 0.3, 0.2, 0.003, 0.5)
_beam_jit(np.random.randn(30), np.random.randn(50), 25, 8, 15., 100.)
_q = np.random.randn(40); _r = np.random.randn(50)
_dtw_sakoe_chiba(_q, _r, 10)
_dtw_stochastic_realizations(_q, _r, 10, 3, 2.0)
 
 
def robust_slope(x, y, w=None):
    x = np.asarray(x, float); y = np.asarray(y, float)
    m = np.isfinite(x) & np.isfinite(y)
    if m.sum() < 2 or np.std(x[m]) < 1e-6: return 0.
    return float(np.polyfit(x[m], y[m], 1)[0])
 
 
def affine_cal(kgr, tw_at_k, min_pts=20):
    v = np.isfinite(kgr) & np.isfinite(tw_at_k)
    if v.sum() < min_pts or np.std(tw_at_k[v]) < 1e-6:
        return 1., float(np.nanmean(kgr) - np.nanmean(tw_at_k)) if v.any() else 0.
    a, b = np.polyfit(tw_at_k[v], kgr[v], 1); return float(a), float(b)
 
 
def seg_b_well(ktvt, kz, form_col):
    bv = ktvt + kz - form_col; n = len(bv)
    b_full = float(np.median(bv))
    b_late = float(np.median(bv[max(0, n - 50):])) if n >= 5 else b_full
    t1, t2 = n // 3, 2 * n // 3
    b_early = float(np.median(bv[:max(1, t1)])) if t1 > 0 else b_full
    b_mid = float(np.median(bv[t1:max(t1 + 1, t2)])) if t2 > t1 else b_full
    w = np.exp(0.02 * np.arange(n)); w /= w.sum()
    b_wls = float(np.dot(w, bv))
    return b_full, b_early, b_mid, b_late, b_wls
 
 
def multi_scale_ncc(kgr, ktvt, hgr, hws=(8, 15, 25), stride=3):
    out = []
    for hw in hws:
        win = 2 * hw + 1; nk = len(kgr); nh = len(hgr)
        if nk < win + 1 or nh == 0:
            out.append((np.full(nh, ktvt[-1], np.float32), np.zeros(nh, np.float32))); continue
        kg = pd.Series(kgr).rolling(5, center=True, min_periods=1).mean().values.astype(np.float32)
        hg = pd.Series(hgr).rolling(5, center=True, min_periods=1).mean().values.astype(np.float32)
        sts = np.arange(0, nk - win + 1, stride, dtype=np.int32); M = len(sts)
        if M == 0:
            out.append((np.full(nh, ktvt[-1], np.float32), np.zeros(nh, np.float32))); continue
        C = kg[sts[:, None] + np.arange(win, dtype=np.int32)[None, :]].astype(np.float32)
        Cn = (C - C.mean(1, keepdims=True)) / (C.std(1, keepdims=True) + 1e-6)
        hp = np.pad(hg, hw, mode='edge')
        H = hp[np.arange(nh)[:, None] + np.arange(win)[None, :]].astype(np.float32)
        Hn = (H - H.mean(1, keepdims=True)) / (H.std(1, keepdims=True) + 1e-6)
        ncc = Hn @ Cn.T / win; best = ncc.argmax(1); score = ncc.max(1).astype(np.float32)
        out.append((ktvt[np.clip(sts[best] + hw, 0, nk - 1)].astype(np.float32), score))
    tvts = np.stack([o[0] for o in out], 1); scores = np.stack([o[1] for o in out], 1)
    sw = np.exp(3. * scores); sw /= sw.sum(1, keepdims=True) + 1e-9
    sc_ens = (tvts * sw).sum(1).astype(np.float32)
    return out, sc_ens
 
 
class FormationPlaneKNN:
    def __init__(self, well_ids, data_dir):
        rows = []
        for wid in well_ids:
            p = data_dir / f'{wid}__horizontal_well.csv'
            try: df = pd.read_csv(p, usecols=['X', 'Y'] + FORMATIONS).dropna()
            except: continue
            if len(df) == 0: continue
            row = {'wid': wid, 'x': float(df['X'].median()), 'y': float(df['Y'].median())}
            for c in FORMATIONS: row[f'{c}_m'] = float(df[c].median())
            rows.append(row)
        self.df = pd.DataFrame(rows); self.wmap = {w: i for i, w in enumerate(self.df['wid'])}
        xy = self.df[['x', 'y']].to_numpy(); self.scale = np.where(xy.std(0) < 1e-3, 1., xy.std(0))
        self.tree = cKDTree(xy / self.scale)
        self.xa = self.df['x'].to_numpy(); self.ya = self.df['y'].to_numpy()
        self.fa = self.df[[f'{c}_m' for c in FORMATIONS]].to_numpy(np.float64)
 
    def impute(self, xy_q, self_wid=None, k=PLANE_K):
        q = xy_q / self.scale; nf = min(k + 5, len(self.df))
        dist, idx = self.tree.query(q, k=nf, workers=-1)
        if self_wid in self.wmap: dist = np.where(idx == self.wmap[self_wid], np.inf, dist)
        ord = np.argpartition(dist, min(k - 1, nf - 1), 1)[:, :k]
        dk = np.take_along_axis(dist, ord, 1); ik = np.take_along_axis(idx, ord, 1)
        vk = np.isfinite(dk); w = np.where(vk, 1. / (dk + 1e-3), 0.).astype(np.float64)
        xn = self.xa[ik]; yn = self.ya[ik]; fn = self.fa[ik]; wx = w * xn; wy = w * yn
        A = np.zeros((len(q), 3, 3))
        A[:, 0, 0] = (wx * xn).sum(1); A[:, 0, 1] = (wx * yn).sum(1); A[:, 0, 2] = wx.sum(1)
        A[:, 1, 0] = A[:, 0, 1]; A[:, 1, 1] = (wy * yn).sum(1); A[:, 1, 2] = wy.sum(1)
        A[:, 2, 0] = A[:, 0, 2]; A[:, 2, 1] = A[:, 1, 2]; A[:, 2, 2] = w.sum(1)
        A[:, 0, 0] += 1e-9; A[:, 1, 1] += 1e-9; A[:, 2, 2] += 1e-9
        rhs = np.stack([(wx[:, :, None] * fn).sum(1), (wy[:, :, None] * fn).sum(1),
                        (w[:, :, None] * fn).sum(1)], 1)
        try:
            coef = np.linalg.solve(A, rhs)
        except:
            coef = np.zeros((len(q), 3, 6))
            for r in range(len(q)):
                try: coef[r] = np.linalg.pinv(A[r]) @ rhs[r]
                except: pass
        Xq = xy_q[:, 0]; Yq = xy_q[:, 1]
        pred = (Xq[:, None] * coef[:, 0, :] + Yq[:, None] * coef[:, 1, :] + coef[:, 2, :]).astype(np.float32)
        pred[~vk.any(1)] = self.fa.mean(0)
        return pred, np.where(vk, dk, np.inf).min(1).astype(np.float32)
 
 
class DenseANCCImputer:
    def __init__(self, well_ids, data_dir, spw=DENSE_SPW):
        xs, ys, anccs, wids = [], [], [], []
        for wid in well_ids:
            p = data_dir / f'{wid}__horizontal_well.csv'
            try: df = pd.read_csv(p, usecols=['X', 'Y', 'ANCC']).dropna()
            except: continue
            if len(df) == 0: continue
            ix = np.linspace(0, len(df) - 1, min(spw, len(df)), dtype=int); s = df.iloc[ix]
            xs.append(s['X'].values); ys.append(s['Y'].values)
            anccs.append(s['ANCC'].values); wids.extend([wid] * len(s))
        self.xy = np.column_stack([np.concatenate(xs), np.concatenate(ys)])
        self.ancc = np.concatenate(anccs).astype(np.float32); self.wids = np.array(wids)
        self.scale = np.where(self.xy.std(0) < 1e-3, 1., self.xy.std(0))
        self.tree = cKDTree(self.xy / self.scale)
 
    def impute(self, xy_q, self_wid=None, k=DENSE_K, nfetch=5000):
        xy_q = np.atleast_2d(xy_q); q = xy_q / self.scale; nf = min(nfetch, len(self.ancc))
        dist, idx = self.tree.query(q, k=nf, workers=-1)
        if self_wid: dist = np.where(self.wids[idx] == self_wid, np.inf, dist)
        ord = np.argpartition(dist, min(k - 1, nf - 1), 1)[:, :k]
        dk = np.take_along_axis(dist, ord, 1); ik = np.take_along_axis(idx, ord, 1)
        vk = np.isfinite(dk); w = np.where(vk, 1. / (dk + 1e-3), 0.)
        sw = w.sum(1); safe = np.where(sw < 1e-9, 1., sw); an = self.ancc[ik]
        ap = (an * w).sum(1) / safe; ap = np.where(sw < 1e-9, float(self.ancc.mean()), ap)
        var = ((an - ap[:, None]) ** 2 * w).sum(1) / safe
        return ap.astype(np.float32), np.sqrt(np.maximum(var, 0.)).astype(np.float32), \
               np.where(vk, dk, np.inf).min(1).astype(np.float32)
 
 
hw_paths = sorted((CFG.dataset_path / "train").glob('*__horizontal_well.csv'))
train_wids = [p.stem.replace('__horizontal_well', '') for p in hw_paths]
FI = FormationPlaneKNN(train_wids, CFG.dataset_path / "train")
DI = DenseANCCImputer(train_wids, CFG.dataset_path / "train")
 
_FI = FI; _DI = DI
ANCH_OFFS = np.array([-80, -40, -20, -10, -5, 0, 5, 10, 20, 40, 80], np.float32)
BEAM_OFFS = np.array([-40, -20, -10, -5, -3, 0, 3, 5, 10, 20, 40], np.float32)
SC_OFFS   = np.array([-30, -15, -8, -4, -2, 0, 2, 4, 8, 15, 30], np.float32)
PF_OFFS   = np.array([-30, -15, -8, -4, -2, 0, 2, 4, 8, 15, 30], np.float32)
DTW_OFFS  = np.array([-20, -10, -5, -2, 0, 2, 5, 10, 20], np.float32)
 
 
def build_well(hw_path, tw_path, is_train):
    global _FI, _DI
    wid = Path(hw_path).stem.replace('__horizontal_well', '')
    try:
        hw = pd.read_csv(hw_path); tw = pd.read_csv(tw_path).sort_values('TVT')
    except:
        return None
    if is_train and 'TVT' not in hw.columns: return None
    kn = hw[hw['TVT_input'].notna()]; ev = hw[hw['TVT_input'].isna()]
    if len(ev) == 0 or len(kn) < 10: return None
    if is_train and hw['TVT'].isna().all(): return None
    tw_tvt = tw['TVT'].to_numpy(np.float32); tw_gr = tw['GR'].to_numpy(np.float32)
    if len(tw_tvt) < 3: return None
 
    pf_a, std_a = run_pf_ancc(hw, tw_tvt, tw_gr)
    if len(pf_a) == 0: return None
    pf_z, std_z = run_pf_z(hw, tw_tvt, tw_gr)
    pf_use = pf_a.astype(np.float32); std_use = std_a.astype(np.float32)
    has_z = len(pf_z) == len(pf_a) and not np.any(np.isnan(pf_z))
 
    lk = kn.iloc[-1]; last_tvt = float(lk['TVT_input'])
    gr_full = hw['GR'].astype(float).interpolate(limit_direction='both').fillna(float(np.nanmean(tw_gr)))
    hgr = gr_full.iloc[ev.index[0]:].to_numpy(np.float32)
    kgr = gr_full.iloc[:len(kn)].to_numpy(np.float32)
 
    bpaths = {}
    for (bs, mc, es, r, tag) in BEAMS:
        bpaths[tag] = beam_search(hgr, tw_tvt, tw_gr, last_tvt, bs, mc, es, r)
    beam_ref = (bpaths['cons'] + bpaths['sm5']) / 2.
 
    ktvt = kn['TVT_input'].to_numpy(np.float32)
    sc_res, sc_ens = multi_scale_ncc(kgr, ktvt, hgr, hws=(8, 15, 25), stride=3)
    sc8, sc8s = sc_res[0]; sc15, sc15s = sc_res[1]; sc25, sc25s = sc_res[2]
    sc_cons = (sc8 + sc15 + sc25) / 3.
    sc_trust = float(np.clip(len(kn) / 200., 0., 0.6))
    hyb_ref = (1 - sc_trust) * beam_ref + sc_trust * sc_ens
 
    full_gr = gr_full.values.astype(np.float32)
    dtw_tvts_ms, dtw_slopes_ms, dtw_costs_ms, dtw_ens_ms = run_dtw_multiscale(
        full_gr, tw_tvt, tw_gr, last_tvt, radii=DTW_RADII
    )
 
    dtw_mean_stoch, dtw_std_stoch, dtw_cv_stoch = run_dtw_stochastic(
        full_gr, tw_tvt, tw_gr, last_tvt, radius=50, K=DTW_STOCH_K, temperature=DTW_STOCH_TEMP
    )
 
    nh = len(ev)
    ev_start = ev.index[0]
 
    def _ev_slice(arr):
        return arr[ev_start:ev_start + nh].astype(np.float32)
 
    dtw_ens_ev = _ev_slice(dtw_ens_ms)
    dtw_mean_ev = _ev_slice(dtw_mean_stoch)
    dtw_std_ev = _ev_slice(dtw_std_stoch)
    dtw_cv_ev = _ev_slice(dtw_cv_stoch)
 
    dtw_per_radius_ev = {}
    dtw_slope_ev = {}
    for r in DTW_RADII:
        dtw_per_radius_ev[r] = _ev_slice(dtw_tvts_ms[r])
        dtw_slope_ev[r] = _ev_slice(dtw_slopes_ms[r])
 
    dtw_slope_mean_ev = np.stack([dtw_slope_ev[r] for r in DTW_RADII], 1).mean(1).astype(np.float32)
    dtw_ens_slope_ev = np.stack([dtw_slope_ev[r] for r in DTW_RADII], 1).mean(1).astype(np.float32)
 
    dtw_cost_arr = np.array([dtw_costs_ms[r] for r in DTW_RADII], dtype=np.float32)
    dtw_cost_min = float(dtw_cost_arr.min())
    dtw_cost_range = float(dtw_cost_arr.max() - dtw_cost_arr.min())
 
    tw_at_k = np.interp(ktvt, tw_tvt, tw_gr).astype(np.float32)
    a_cal, b_cal = affine_cal(kgr, tw_at_k)
    kmd = kn['MD'].to_numpy(np.float32); kz = kn['Z'].to_numpy(np.float32)
    pfx_rmse = float(np.sqrt(np.mean((kgr - tw_at_k) ** 2)))
    slp_all = robust_slope(kmd, ktvt); slp_50 = robust_slope(kmd[-50:], ktvt[-50:])
    slp_z = robust_slope(kz, ktvt)
 
    swid = wid if is_train else None
    xy_ev = ev[['X', 'Y']].to_numpy(np.float64); xy_kn = kn[['X', 'Y']].to_numpy(np.float64)
    form_ev, knn_d = _FI.impute(xy_ev, self_wid=swid)
    form_kn, _ = _FI.impute(xy_kn, self_wid=swid)
    z_kn = kn['Z'].to_numpy(np.float32); z_ev = ev['Z'].to_numpy(np.float32)
 
    tvt_fs = {}; form_rmse = {}; form_list = []
    for fi2, fn in enumerate(FORMATIONS):
        b_full, b_early, b_mid, b_late, b_wls = seg_b_well(ktvt, z_kn, form_kn[:, fi2])
        tvt_f = (-z_ev + form_ev[:, fi2] + b_full).astype(np.float32)
        tvt_fw = (-z_ev + form_ev[:, fi2] + b_wls).astype(np.float32)
        tvt_f50 = (-z_ev + form_ev[:, fi2] + b_late).astype(np.float32)
        tvt_fs[f'tvtF_{fn}'] = tvt_f; tvt_fs[f'tvtFw_{fn}'] = tvt_fw
        tvt_fs[f'tvtF50_{fn}'] = tvt_f50
        tvt_fs[f'bw_{fn}'] = np.float32(b_full); tvt_fs[f'bww_{fn}'] = np.float32(b_wls)
        tvt_fs[f'bw50_{fn}'] = np.float32(b_late)
        tvt_fs[f'bw_early_{fn}'] = np.float32(b_early)
        tvt_fs[f'bw_mid_{fn}'] = np.float32(b_mid)
        form_rmse[fn] = float(np.sqrt(np.mean((ktvt - (-z_kn + form_kn[:, fi2] + b_full)) ** 2)))
        form_list.append(tvt_f)
 
    fs = np.stack(form_list, 1)
    form_mean_d = (fs.mean(1) - last_tvt).astype(np.float32)
    form_std_d = fs.std(1).astype(np.float32)
    form_rng_d = (fs.max(1) - fs.min(1)).astype(np.float32)
 
    d_ancc, d_std, d_dist = _DI.impute(xy_ev, self_wid=swid)
    d_kn, d_std_kn, _ = _DI.impute(xy_kn, self_wid=swid)
    b_vd = ktvt + z_kn - d_kn
    _, b_de, b_dm, b_dl, b_dw = seg_b_well(ktvt, z_kn, d_kn)
    b_d = float(np.median(b_vd))
    tvt_dense = (-z_ev + d_ancc + b_d).astype(np.float32)
    tvt_densew = (-z_ev + d_ancc + b_dw).astype(np.float32)
    tvt_dense50 = (-z_ev + d_ancc + b_dl).astype(np.float32)
    res_kn = ktvt + z_kn - d_kn
    d_rmse = float(np.sqrt(np.mean(res_kn ** 2)))
    d_bias = float(np.mean(res_kn)); d_nb_std = float(np.mean(d_std_kn))
 
    all_sigs = [pf_use] + [p for p in bpaths.values()] + \
               [sc8, sc15, sc25, sc_ens, tvt_fs['tvtF_ANCC'], tvt_dense, dtw_ens_ev]
    sig_mat = np.stack(all_sigs, 1)
    sig_std = sig_mat.std(1).astype(np.float32)
    sig_mean = (sig_mat.mean(1) - last_tvt).astype(np.float32)
 
    gr_s = pd.Series(gr_full.values); rolls = {}
    for w in [5, 21, 51, 101]:
        r = gr_s.rolling(w, center=True, min_periods=1)
        rolls[f'grm{w}'] = r.mean().iloc[ev.index].values.astype(np.float32)
        rolls[f'grs{w}'] = r.std().fillna(0).iloc[ev.index].values.astype(np.float32)
    for lag in [1, 5, 15, 30]:
        rolls[f'glag{lag}'] = gr_s.shift(lag).bfill().iloc[ev.index].values.astype(np.float32)
        rolls[f'glead{lag}'] = gr_s.shift(-lag).ffill().iloc[ev.index].values.astype(np.float32)
    gr_d1 = gr_s.diff().fillna(0.).iloc[ev.index].values.astype(np.float32)
    gr_d2 = gr_s.diff().diff().fillna(0.).iloc[ev.index].values.astype(np.float32)
    gr_env = gr_s.rolling(21, center=True, min_periods=1).max().iloc[ev.index].values.astype(np.float32)
    gr_nrg = np.sqrt(np.maximum((gr_s ** 2).rolling(21, center=True, min_periods=1).mean(), 0.)
                     ).iloc[ev.index].values.astype(np.float32)
 
    hmd = ev['MD'].to_numpy(np.float32); md_since = hmd - float(lk['MD'])
    slp_b_all = (last_tvt + slp_all * md_since).astype(np.float32)
    slp_b_50 = (last_tvt + slp_50 * md_since).astype(np.float32)
 
    mdd = hw['MD'].diff().replace(0, np.nan)
    dzdmd = (hw['Z'].diff() / mdd).iloc[ev.index].values.astype(np.float32)
    dxdmd = (hw['X'].diff() / mdd).iloc[ev.index].values.astype(np.float32)
    dydmd = (hw['Y'].diff() / mdd).iloc[ev.index].values.astype(np.float32)
 
    frac = (np.arange(nh) / max(nh - 1, 1)).astype(np.float32)
 
    def sc(v): return np.full(nh, np.float32(v), np.float32)
 
    feats = {
        'well': wid, 'id': [f'{wid}_{i}' for i in ev.index],
        'last_known_tvt': sc(last_tvt),
        'pf_ancc': pf_use, 'pf_ancc_std': std_use,
        'pf_ancc_delta': (pf_use - last_tvt).astype(np.float32),
        'pf_z': (pf_z.astype(np.float32) if has_z else sc(last_tvt)),
        'pf_z_delta': ((pf_z - last_tvt).astype(np.float32) if has_z else sc(0.)),
        'pf_vs_z': ((pf_use - pf_z.astype(np.float32)) if has_z else sc(0.)),
        **{f'beam_{t}_d': (p - np.float32(last_tvt)).astype(np.float32) for t, p in bpaths.items()},
        'beam_mean_d': np.stack([(p - last_tvt) for p in bpaths.values()], 1).mean(1).astype(np.float32),
        'beam_std_d': np.stack([(p - last_tvt) for p in bpaths.values()], 1).std(1).astype(np.float32),
        'beam_med_d': np.median(np.stack([(p - last_tvt) for p in bpaths.values()], 1), 1).astype(np.float32),
        'sc8_d': (sc8 - np.float32(last_tvt)).astype(np.float32), 'sc8_sc': sc8s,
        'sc15_d': (sc15 - np.float32(last_tvt)).astype(np.float32), 'sc15_sc': sc15s,
        'sc25_d': (sc25 - np.float32(last_tvt)).astype(np.float32), 'sc25_sc': sc25s,
        'sc_cons_d': (sc_cons - np.float32(last_tvt)).astype(np.float32),
        'sc_ens_d': (sc_ens - np.float32(last_tvt)).astype(np.float32),
        'sc_trust': sc(sc_trust), 'hyb_d': (hyb_ref - np.float32(last_tvt)).astype(np.float32),
        'sig_std': sig_std, 'sig_mean_d': sig_mean,
        **tvt_fs,
        **{f'frm_rmse_{fn}': sc(form_rmse[fn]) for fn in FORMATIONS},
        'form_mean_d': form_mean_d, 'form_std_d': form_std_d, 'form_rng_d': form_rng_d,
        'spatial_ancc_d': (form_ev[:, 0] - np.float32(np.interp(last_tvt, tw_tvt, tw_gr))),
        'spatial_knn_dist': knn_d,
        'dense_ancc': d_ancc, 'dense_std': d_std, 'dense_dist': d_dist,
        'tvt_dense_d': (tvt_dense - last_tvt).astype(np.float32),
        'tvt_densew_d': (tvt_densew - last_tvt).astype(np.float32),
        'tvt_dense50_d': (tvt_dense50 - last_tvt).astype(np.float32),
        'dense_rmse': sc(d_rmse), 'dense_bias': sc(d_bias), 'dense_nb_std': sc(d_nb_std),
        'pf_vs_spatial': (pf_use - tvt_fs['tvtF_ANCC']).astype(np.float32),
        'pf_vs_dense': (pf_use - tvt_dense).astype(np.float32),
        'spatial_vs_dense': (tvt_fs['tvtF_ANCC'] - tvt_dense).astype(np.float32),
        'beam_vs_spatial': (bpaths['cons'] - tvt_fs['tvtF_ANCC']).astype(np.float32),
        'sc_vs_beam': (sc_ens - bpaths['cons']).astype(np.float32),
        'dtw_ens_d': (dtw_ens_ev - last_tvt).astype(np.float32),
        'dtw_stoch_mean_d': (dtw_mean_ev - last_tvt).astype(np.float32),
        'dtw_stoch_std': dtw_std_ev,
        'dtw_stoch_cv': dtw_cv_ev,
        'dtw_slope_mean': dtw_slope_mean_ev,
        **{f'dtw_r{r}_d': (dtw_per_radius_ev[r] - last_tvt).astype(np.float32) for r in DTW_RADII},
        **{f'dtw_slope_r{r}': dtw_slope_ev[r] for r in DTW_RADII},
        'dtw_cost_min': sc(dtw_cost_min),
        'dtw_cost_range': sc(dtw_cost_range),
        'dtw_vs_beam': (dtw_ens_ev - bpaths['cons']).astype(np.float32),
        'dtw_vs_pf': (dtw_ens_ev - pf_use).astype(np.float32),
        'dtw_vs_sc': (dtw_ens_ev - sc_ens).astype(np.float32),
        **{f'tddtw{int(o)}': hgr - np.interp(dtw_ens_ev + o, tw_tvt, tw_gr).astype(np.float32)
           for o in DTW_OFFS},
        'cal_a': sc(a_cal), 'cal_b': sc(b_cal),
        'pfx_rmse': sc(pfx_rmse), 'known_len': sc(len(kn)), 'eval_len': sc(nh),
        'slp_all': sc(slp_all), 'slp_50': sc(slp_50), 'slp_z': sc(slp_z),
        'slp_b_d_all': (slp_b_all - last_tvt).astype(np.float32),
        'slp_b_d_50': (slp_b_50 - last_tvt).astype(np.float32),
        'ktvt_range': sc(float(np.ptp(ktvt))), 'ktvt_std': sc(float(ktvt.std())),
        'md_since': md_since, 'frac': frac, 'frac2': frac ** 2, 'sqrt_frac': np.sqrt(frac),
        'z': z_ev,
        'dx': (ev['X'] - float(lk['X'])).to_numpy(np.float32),
        'dy': (ev['Y'] - float(lk['Y'])).to_numpy(np.float32),
        'dz': (z_ev - float(lk['Z'])).astype(np.float32),
        'dxy': np.sqrt((ev['X'] - float(lk['X'])) ** 2 + (ev['Y'] - float(lk['Y'])) ** 2).to_numpy(np.float32),
        'dzdmd': dzdmd, 'dxdmd': dxdmd, 'dydmd': dydmd,
        'gr': hgr, 'gr_d1': gr_d1, 'gr_d2': gr_d2, 'gr_env': gr_env, 'gr_nrg': gr_nrg,
        'gr_vs_tw_anc': hgr - np.float32(np.interp(last_tvt, tw_tvt, tw_gr)),
        'gr_vs_slp_all': hgr - np.interp(slp_b_all, tw_tvt, tw_gr).astype(np.float32),
        **{f'tda{int(o)}': hgr - np.float32(np.interp(last_tvt + o, tw_tvt, tw_gr)) for o in ANCH_OFFS},
        **{f'tdbc{int(o)}': hgr - np.interp(beam_ref + o, tw_tvt, tw_gr).astype(np.float32) for o in BEAM_OFFS},
        **{f'tdsc{int(o)}': hgr - np.interp(sc_ens + o, tw_tvt, tw_gr).astype(np.float32) for o in SC_OFFS},
        **{f'tdpf{int(o)}': hgr - np.interp(pf_use + o, tw_tvt, tw_gr).astype(np.float32) for o in PF_OFFS},
        'tw_range': sc(float(np.ptp(tw_tvt))), 'tw_gr_mean': sc(float(tw_gr.mean())),
    }
    for k, v in rolls.items(): feats[k] = v
    result = pd.DataFrame(feats)
    if is_train:
        if 'TVT' not in ev.columns or ev['TVT'].isna().all(): return None
        result['target'] = (ev['TVT'].to_numpy(np.float32) - np.float32(last_tvt))
    return result
 
 
def build_dataset(paths, is_train, label):
    args = [(str(p), str(p.parent / f'{p.stem.replace("__horizontal_well", "")}__typewell.csv'), is_train)
            for p in paths
            if (p.parent / f'{p.stem.replace("__horizontal_well", "")}__typewell.csv').exists()]
    res = Parallel(n_jobs=NCPU, prefer='threads', verbose=0)(
        delayed(build_well)(hp, tp, it) for hp, tp, it in args)
    parts = [r for r in res if r is not None]
    return pd.concat(parts, ignore_index=True) if parts else pd.DataFrame()

# %%
if (CFG.artifacts_path / "data" / "train.csv").exists():
    train_df = pd.read_csv(CFG.artifacts_path / "data" / "train.csv", low_memory=False)
else:
    train_df = build_dataset(hw_paths, is_train=True, label="train")
    train_df.to_csv("train.csv", index=False)
 
test_paths = sorted((CFG.dataset_path / "test").glob('*__horizontal_well.csv'))
test_df = build_dataset(test_paths, is_train=False, label="test")
 
features = [c for c in train_df.columns if c not in {'well', 'id', 'target'}]
 
X = train_df[features]
y = train_df['target']
g = train_df['well']
 
X_test = test_df[features]

# %% [markdown]
# # 3. Training

# %%
lgb_params_base = dict(
    boosting_type="gbdt", num_leaves=255, min_child_samples=15,
    subsample=0.8, subsample_freq=1, colsample_bytree=0.8,
    reg_lambda=3.0, reg_alpha=0.05, objective="regression",
    verbose=-1, n_jobs=-1, device_type="gpu", gpu_use_dp=False, max_bin=255,
)
 
lgb_params = [
    dict(learning_rate=0.025, n_estimators=8000, seed=42, **lgb_params_base),
    dict(learning_rate=0.020, n_estimators=8000, seed=7, **lgb_params_base),
    dict(learning_rate=0.030, n_estimators=8000, seed=123, **lgb_params_base),
]
 
cb_params_base = dict(
    iterations=8000, depth=7, l2_leaf_reg=2.0,
    min_data_in_leaf=15, border_count=254,
    loss_function="RMSE", task_type="GPU", devices="0",
    od_type="Iter", od_wait=300, verbose=0,
)
 
cb_params = [
    dict(learning_rate=0.025, random_seed=42, **cb_params_base),
    dict(learning_rate=0.020, random_seed=7, **cb_params_base),
    dict(learning_rate=0.030, random_seed=123, **cb_params_base),
]

# %%
oof_preds = {}
test_preds = {}

overall_scores = {}
fold_scores = {}

# %% [markdown]
# ## 3.1 LightGBM

# %%
def train_lightgbm(params, name):
    if (CFG.artifacts_path / "models" / name).exists():
        path = CFG.artifacts_path / "models" / name
        models = joblib.load(path / "models.pkl")
        oof_preds = joblib.load(path / "oof_preds.pkl")
        test_preds = np.zeros(len(test_df), np.float32)
        fold_scores = []
        print(f"Loading {name}\n")
        splits = CFG.cv.split(X, y, groups=g)
        for fold_idx, (train_idx, valid_idx) in enumerate(splits):
            m = models[fold_idx]
            test_preds += m.predict(X_test, num_iteration=m.best_iteration).astype(np.float32) / CFG.n_splits
            score = root_mean_squared_error(y.iloc[valid_idx], oof_preds[valid_idx])
            fold_scores.append(score)
            print(f"--- Fold {fold_idx} RMSE: {score:.3f}")
        overall_score = root_mean_squared_error(y, oof_preds)
        print(f"\nOverall RMSE: {overall_score:.4f}")
        return oof_preds, test_preds, overall_score, fold_scores
 
    n_est = params.pop('n_estimators')
    oof_preds = np.zeros(len(train_df), np.float32)
    test_preds = np.zeros(len(test_df), np.float32)
    models = []; fold_scores = []
    print(f"Training {name}\n")
    splits = CFG.cv.split(X, y, groups=g)
    for fold_idx, (train_idx, valid_idx) in enumerate(splits):
        d_train = lgb.Dataset(X.iloc[train_idx], label=y.iloc[train_idx])
        d_valid = lgb.Dataset(X.iloc[valid_idx], label=y.iloc[valid_idx], reference=d_train)
        m = lgb.train(params, d_train, valid_sets=[d_valid], num_boost_round=n_est,
                      callbacks=[lgb.early_stopping(250, verbose=False)])
        models.append(m)
        oof_preds[valid_idx] = m.predict(X.iloc[valid_idx], num_iteration=m.best_iteration).astype(np.float32)
        test_preds += m.predict(X_test, num_iteration=m.best_iteration).astype(np.float32) / CFG.n_splits
        score = root_mean_squared_error(y.iloc[valid_idx], oof_preds[valid_idx])
        fold_scores.append(score)
        print(f"--- Fold {fold_idx} RMSE: {score:.3f}")
    overall_score = root_mean_squared_error(y, oof_preds)
    print(f"\nOverall RMSE: {overall_score:.4f}")
    os.makedirs(f"models/{name}", exist_ok=True)
    joblib.dump(models, f"models/{name}/models.pkl")
    joblib.dump(oof_preds, f"models/{name}/oof_preds.pkl")
    return oof_preds, test_preds, overall_score, fold_scores
 
 
for i in range(3):
    _oof_preds, _test_preds, _overall_score, _fold_scores = train_lightgbm(lgb_params[i], f"lightgbm-{i + 1}")
    oof_preds[f"lightgbm-{i + 1}"] = _oof_preds
    test_preds[f"lightgbm-{i + 1}"] = _test_preds
    overall_scores[f"lightgbm-{i + 1}"] = _overall_score
    fold_scores[f"lightgbm-{i + 1}"] = _fold_scores
    print("\n\n")
# Out:
# Loading lightgbm-1
#
# --- Fold 0 RMSE: 9.805
# --- Fold 1 RMSE: 11.186
# --- Fold 2 RMSE: 9.340
# --- Fold 3 RMSE: 12.158
# --- Fold 4 RMSE: 11.238
#
# Overall RMSE: 10.7947
#
#
#
# Loading lightgbm-2
#
# --- Fold 0 RMSE: 9.869
# --- Fold 1 RMSE: 11.196
# --- Fold 2 RMSE: 9.323
# --- Fold 3 RMSE: 11.911
# --- Fold 4 RMSE: 11.282
#
# Overall RMSE: 10.7595
#
#
#
# Loading lightgbm-3
#
# --- Fold 0 RMSE: 9.827
# --- Fold 1 RMSE: 11.091
# --- Fold 2 RMSE: 9.457
# --- Fold 3 RMSE: 11.836
# --- Fold 4 RMSE: 11.325
#
# Overall RMSE: 10.7457

# %% [markdown]
# ## 3.2 CatBoost

# %%
def train_catboost(params, name):
    if (CFG.artifacts_path / "models" / name).exists():
        path = CFG.artifacts_path / "models" / name
        models = joblib.load(path / "models.pkl")
        oof_preds = joblib.load(path / "oof_preds.pkl")
        test_preds = np.zeros(len(test_df), np.float32)
        fold_scores = []
        print(f"Loading {name}\n")
        splits = CFG.cv.split(X, y, groups=g)
        for fold_idx, (train_idx, valid_idx) in enumerate(splits):
            m = models[fold_idx]
            test_preds += m.predict(X_test).astype(np.float32) / CFG.n_splits
            score = root_mean_squared_error(y.iloc[valid_idx], oof_preds[valid_idx])
            fold_scores.append(score)
            print(f"--- Fold {fold_idx} RMSE: {score:.3f}")
        overall_score = root_mean_squared_error(y, oof_preds)
        print(f"\nOverall RMSE: {overall_score:.4f}")
        return oof_preds, test_preds, overall_score, fold_scores
 
    oof_preds = np.zeros(len(train_df), np.float32)
    test_preds = np.zeros(len(test_df), np.float32)
    models = []; fold_scores = []
    print(f"Training {name}\n")
    splits = CFG.cv.split(X, y, groups=g)
    for fold_idx, (train_idx, valid_idx) in enumerate(splits):
        m = CatBoostRegressor(**params)
        m.fit(Pool(X.iloc[train_idx].values, label=y.iloc[train_idx].values),
              eval_set=Pool(X.iloc[valid_idx].values, label=y.iloc[valid_idx].values),
              use_best_model=True)
        models.append(m)
        oof_preds[valid_idx] = m.predict(X.iloc[valid_idx]).astype(np.float32)
        test_preds += m.predict(X_test).astype(np.float32) / CFG.n_splits
        score = root_mean_squared_error(y.iloc[valid_idx], oof_preds[valid_idx])
        fold_scores.append(score)
        print(f"--- Fold {fold_idx} RMSE: {score:.3f}")
    overall_score = root_mean_squared_error(y, oof_preds)
    print(f"\nOverall RMSE: {overall_score:.4f}")
    os.makedirs(f"models/{name}", exist_ok=True)
    joblib.dump(models, f"models/{name}/models.pkl")
    joblib.dump(oof_preds, f"models/{name}/oof_preds.pkl")
    return oof_preds, test_preds, overall_score, fold_scores
 
 
for i in range(3):
    _oof_preds, _test_preds, _overall_score, _fold_scores = train_catboost(cb_params[i], f"catboost-{i + 1}")
    oof_preds[f"catboost-{i + 1}"] = _oof_preds
    test_preds[f"catboost-{i + 1}"] = _test_preds
    overall_scores[f"catboost-{i + 1}"] = _overall_score
    fold_scores[f"catboost-{i + 1}"] = _fold_scores
    print("\n\n")
# Out:
# Loading catboost-1
#
# --- Fold 0 RMSE: 10.061
# --- Fold 1 RMSE: 10.674
# --- Fold 2 RMSE: 9.206
# --- Fold 3 RMSE: 11.613
# --- Fold 4 RMSE: 11.238
#
# Overall RMSE: 10.5930
#
#
#
# Loading catboost-2
#
# --- Fold 0 RMSE: 10.037
# --- Fold 1 RMSE: 10.670
# --- Fold 2 RMSE: 9.237
# --- Fold 3 RMSE: 11.628
# --- Fold 4 RMSE: 11.184
#
# Overall RMSE: 10.5849
#
#
#
# Loading catboost-3
#
# --- Fold 0 RMSE: 10.014
# --- Fold 1 RMSE: 10.533
# --- Fold 2 RMSE: 9.194
# --- Fold 3 RMSE: 11.444
# --- Fold 4 RMSE: 11.038
#
# Overall RMSE: 10.4742

# %% [markdown]
# # 4. Hill climbing

# %%
oof_preds = pd.DataFrame(oof_preds)
test_preds = pd.DataFrame(test_preds)

# === ADDED: try lightgbm-4 if cached and dump full OOFs / test preds for stacker ===
try:
    lgb4_path = CFG.artifacts_path / 'models' / 'lightgbm-4'
    if lgb4_path.exists():
        print('Loading bonus model lightgbm-4...')
        lgb4_models = joblib.load(lgb4_path / 'models.pkl')
        lgb4_oof = joblib.load(lgb4_path / 'oof_preds.pkl')
        lgb4_test = np.zeros(len(test_df), np.float32)
        splits = CFG.cv.split(X, y, groups=g)
        for fi, (_, _v) in enumerate(splits):
            lgb4_test += lgb4_models[fi].predict(X_test, num_iteration=lgb4_models[fi].best_iteration).astype(np.float32) / CFG.n_splits
        oof_preds['lightgbm-4'] = lgb4_oof
        test_preds['lightgbm-4'] = lgb4_test
        sc4 = root_mean_squared_error(y, lgb4_oof)
        print(f'lightgbm-4 OOF: {sc4:.4f}')
        overall_scores['lightgbm-4'] = sc4
        fold_scores['lightgbm-4'] = [sc4] * CFG.n_splits
    else:
        print('lightgbm-4 not in artifacts; skipping')
except Exception as e:
    print('lightgbm-4 load failed:', e)

# Dump OOF + test preds for downstream stacker
oof_preds.to_csv('oof_preds.csv', index=False)
test_preds.to_csv('test_preds.csv', index=False)
print('Dumped oof_preds.csv shape:', oof_preds.shape, 'test_preds.csv shape:', test_preds.shape)

# Also dump baseline / train.id / target so stacker has full context
import pandas as _pd
tr_meta = _pd.DataFrame({
    'id': train_df['id'].values,
    'baseline_tvt': train_df['last_known_tvt'].values,
    'target_tvt': y.values + train_df['last_known_tvt'].values,
})
te_meta = _pd.DataFrame({
    'id': test_df['id'].values,
    'baseline_tvt': test_df['last_known_tvt'].values,
})
tr_meta.to_csv('train_meta.csv', index=False)
te_meta.to_csv('test_meta.csv', index=False)
print('Dumped train_meta + test_meta')
# Out:
# Loading bonus model lightgbm-4...
# lightgbm-4 OOF: 10.5216
# Dumped oof_preds.csv shape: (3783989, 7) test_preds.csv shape: (14151, 7)
# Dumped train_meta + test_meta

# %%
climber = Climber(
    objective="minimize",
    eval_metric=CFG.metric,
    allow_negative_weights=False,
    precision=0.001,
    score_decimal_places=3,
    n_jobs=-1,
    use_gpu=False
).fit(oof_preds, y)
 
hc_oof_preds = climber.predict(oof_preds)
hc_test_preds = climber.predict(test_preds)
fold_scores["hill-climbing"] = [climber.best_score] * CFG.n_splits
overall_scores["hill-climbing"] = climber.best_score

# %% [markdown]
# # 5. Postprocessing

# %%
def apply_pp(df, md, pd_, alpha, tau, w_pf):
    d = md * (1 - w_pf) + pd_ * w_pf
    if tau:
        d *= (1. - np.exp(-np.maximum(df['md_since'].values, 0.) / tau))
    return d * alpha
 
 
def sg_smooth(df, col, sg_w=17, sg_p=3):
    df = df.copy()
    for _, g in df.groupby('well', sort=False):
        v = g[col].values
        n = len(v)
        wl = min(sg_w, n)
        if wl % 2 == 0: wl -= 1
        if wl >= sg_p + 2: v = savgol_filter(v, wl, sg_p)
        df.loc[g.index, col] = v
    return df

# %%
base = train_df['last_known_tvt'].values
ytrue = y.values + base
pf_oof = (train_df['pf_ancc'].values - base)
 
 
def objective(trial):
    alpha = trial.suggest_float('alpha', 0.5, 1.0, step=0.01)
    tau = trial.suggest_int('tau', 5, 500, step=5)
    w_pf = trial.suggest_float('w_pf', 0, 0.5, step=0.01)
    d = apply_pp(train_df, hc_oof_preds, pf_oof, alpha, tau, w_pf)
    return root_mean_squared_error(ytrue, base + d)
 
 
sampler = optuna.samplers.TPESampler(seed=42, n_startup_trials=50)
study = optuna.create_study(direction="minimize", sampler=sampler)
study.optimize(objective, n_trials=500, n_jobs=-1)
 
overall_scores["hill-climbing (pp)"] = study.best_value
fold_scores["hill-climbing (pp)"] = [study.best_value] * CFG.n_splits
best_pp_params = study.best_params
# Out:
# [I 2026-05-19 00:21:47,287] A new study created in memory with name: no-name-73e55c24-199d-439e-bdb8-bcdb87d0f5cf
# [I 2026-05-19 00:21:47,543] Trial 0 finished with value: 11.920959224749266 and parameters: {'alpha': 0.58, 'tau': 200, 'w_pf': 0.31}. Best is trial 0 with value: 11.920959224749266.
# [I 2026-05-19 00:21:47,549] Trial 2 finished with value: 11.388297063774475 and parameters: {'alpha': 0.6799999999999999, 'tau': 345, 'w_pf': 0.18}. Best is trial 2 with value: 11.388297063774475.
# [I 2026-05-19 00:21:47,552] Trial 3 finished with value: 11.119318573343952 and parameters: {'alpha': 0.8, 'tau': 50, 'w_pf': 0.36}. Best is trial 3 with value: 11.119318573343952.
# [I 2026-05-19 00:21:47,554] Trial 1 finished with value: 10.591604030351865 and parameters: {'alpha': 0.88, 'tau': 65, 'w_pf': 0.08}. Best is trial 1 with value: 10.591604030351865.
# [I 2026-05-19 00:21:47,808] Trial 4 finished with value: 10.510421767249083 and parameters: {'alpha': 0.9199999999999999, 'tau': 105, 'w_pf': 0.09}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:47,822] Trial 5 finished with value: 10.75511833819111 and parameters: {'alpha': 0.8200000000000001, 'tau': 100, 'w_pf': 0.08}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:47,829] Trial 6 finished with value: 11.762009348729265 and parameters: {'alpha': 0.6, 'tau': 430, 'w_pf': 0.09}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:47,840] Trial 7 finished with value: 11.193511447418029 and parameters: {'alpha': 0.7, 'tau': 70, 'w_pf': 0.09}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:48,054] Trial 8 finished with value: 12.069918285804667 and parameters: {'alpha': 0.53, 'tau': 265, 'w_pf': 0.05}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:48,074] Trial 9 finished with value: 11.772964369730763 and parameters: {'alpha': 0.59, 'tau': 365, 'w_pf': 0.01}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:48,083] Trial 10 finished with value: 11.00736755154453 and parameters: {'alpha': 0.87, 'tau': 70, 'w_pf': 0.38}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:48,091] Trial 11 finished with value: 12.089008160908833 and parameters: {'alpha': 0.55, 'tau': 135, 'w_pf': 0.34}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:48,318] Trial 12 finished with value: 10.579543726845035 and parameters: {'alpha': 0.9, 'tau': 40, 'w_pf': 0.15}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:48,319] Trial 13 finished with value: 10.872122088183003 and parameters: {'alpha': 0.8200000000000001, 'tau': 270, 'w_pf': 0.21}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:48,334] Trial 14 finished with value: 10.819719841570167 and parameters: {'alpha': 0.88, 'tau': 75, 'w_pf': 0.3}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:48,340] Trial 15 finished with value: 10.796688030966124 and parameters: {'alpha': 0.94, 'tau': 375, 'w_pf': 0.31}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:48,589] Trial 17 finished with value: 10.568461669992196 and parameters: {'alpha': 0.89, 'tau': 110, 'w_pf': 0.05}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:48,590] Trial 16 finished with value: 11.861386501785596 and parameters: {'alpha': 0.59, 'tau': 35, 'w_pf': 0.32}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:48,592] Trial 18 finished with value: 11.182756514533352 and parameters: {'alpha': 0.95, 'tau': 440, 'w_pf': 0.45}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:48,598] Trial 19 finished with value: 12.020235346404341 and parameters: {'alpha': 0.63, 'tau': 430, 'w_pf': 0.5}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:48,841] Trial 20 finished with value: 10.762244919291184 and parameters: {'alpha': 0.87, 'tau': 125, 'w_pf': 0.25}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:48,848] Trial 21 finished with value: 11.339806590572556 and parameters: {'alpha': 0.78, 'tau': 85, 'w_pf': 0.44}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:48,857] Trial 23 finished with value: 11.459783228200626 and parameters: {'alpha': 0.78, 'tau': 330, 'w_pf': 0.47000000000000003}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:48,859] Trial 22 finished with value: 12.00026397766381 and parameters: {'alpha': 0.6, 'tau': 40, 'w_pf': 0.47000000000000003}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:49,088] Trial 24 finished with value: 11.073396865185888 and parameters: {'alpha': 0.81, 'tau': 330, 'w_pf': 0.32}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:49,109] Trial 25 finished with value: 11.727007898677835 and parameters: {'alpha': 0.61, 'tau': 145, 'w_pf': 0.27}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:49,112] Trial 27 finished with value: 10.94600765263716 and parameters: {'alpha': 0.97, 'tau': 300, 'w_pf': 0.39}. Best is trial 4 with value: 10.510421767249083.
# [I 2026-05-19 00:21:49,118] Trial 26 finished with value: 10.392659925839371 and parameters: {'alpha': 1.0, 'tau': 10, 'w_pf': 0.08}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:49,333] Trial 28 finished with value: 10.514926830863432 and parameters: {'alpha': 0.97, 'tau': 125, 'w_pf': 0.2}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:49,368] Trial 31 finished with value: 11.54755116104002 and parameters: {'alpha': 0.72, 'tau': 70, 'w_pf': 0.46}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:49,375] Trial 29 finished with value: 12.224039644531873 and parameters: {'alpha': 0.53, 'tau': 205, 'w_pf': 0.36}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:49,382] Trial 30 finished with value: 12.220254252986877 and parameters: {'alpha': 0.55, 'tau': 300, 'w_pf': 0.43}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:49,586] Trial 32 finished with value: 11.419309821163829 and parameters: {'alpha': 0.65, 'tau': 10, 'w_pf': 0.1}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:49,610] Trial 33 finished with value: 10.652789136659598 and parameters: {'alpha': 0.97, 'tau': 185, 'w_pf': 0.28}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:49,639] Trial 34 finished with value: 11.278580346172461 and parameters: {'alpha': 0.72, 'tau': 10, 'w_pf': 0.3}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:49,646] Trial 35 finished with value: 11.013146674917344 and parameters: {'alpha': 0.9, 'tau': 110, 'w_pf': 0.4}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:49,836] Trial 36 finished with value: 11.734361811728409 and parameters: {'alpha': 0.66, 'tau': 205, 'w_pf': 0.44}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:49,849] Trial 37 finished with value: 11.337281669138978 and parameters: {'alpha': 0.69, 'tau': 225, 'w_pf': 0.22}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:49,902] Trial 38 finished with value: 11.898409253529506 and parameters: {'alpha': 0.5700000000000001, 'tau': 295, 'w_pf': 0.17}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:49,904] Trial 39 finished with value: 11.819372224962592 and parameters: {'alpha': 0.6, 'tau': 415, 'w_pf': 0.22}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:50,094] Trial 40 finished with value: 11.206325020353914 and parameters: {'alpha': 0.77, 'tau': 95, 'w_pf': 0.36}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:50,098] Trial 41 finished with value: 12.07758146798479 and parameters: {'alpha': 0.56, 'tau': 130, 'w_pf': 0.38}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:50,165] Trial 42 finished with value: 10.627116402219158 and parameters: {'alpha': 0.89, 'tau': 20, 'w_pf': 0.18}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:50,168] Trial 43 finished with value: 12.362344606199526 and parameters: {'alpha': 0.53, 'tau': 205, 'w_pf': 0.49}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:50,321] Trial 44 finished with value: 10.970311222290977 and parameters: {'alpha': 0.9199999999999999, 'tau': 395, 'w_pf': 0.37}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:50,334] Trial 45 finished with value: 10.654537082755462 and parameters: {'alpha': 0.98, 'tau': 50, 'w_pf': 0.29}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:50,393] Trial 46 finished with value: 11.900309361079689 and parameters: {'alpha': 0.56, 'tau': 270, 'w_pf': 0.02}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:50,402] Trial 47 finished with value: 10.932257455642073 and parameters: {'alpha': 0.87, 'tau': 400, 'w_pf': 0.31}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:50,556] Trial 48 finished with value: 11.67427011806157 and parameters: {'alpha': 0.61, 'tau': 340, 'w_pf': 0.09}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:50,586] Trial 49 finished with value: 10.809163236622569 and parameters: {'alpha': 0.8500000000000001, 'tau': 455, 'w_pf': 0.16}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:50,620] Trial 50 finished with value: 11.425702164611549 and parameters: {'alpha': 0.81, 'tau': 350, 'w_pf': 0.48}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:50,636] Trial 51 finished with value: 10.640050344506294 and parameters: {'alpha': 0.9199999999999999, 'tau': 410, 'w_pf': 0.18}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:50,785] Trial 52 finished with value: 10.96077415495414 and parameters: {'alpha': 0.79, 'tau': 475, 'w_pf': 0.02}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:50,856] Trial 53 finished with value: 10.427113325865273 and parameters: {'alpha': 0.99, 'tau': 165, 'w_pf': 0.13}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:50,903] Trial 54 finished with value: 10.509533941080543 and parameters: {'alpha': 0.9299999999999999, 'tau': 165, 'w_pf': 0.12}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:50,921] Trial 55 finished with value: 10.416513847512245 and parameters: {'alpha': 1.0, 'tau': 165, 'w_pf': 0.13}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:51,050] Trial 56 finished with value: 10.410118473045324 and parameters: {'alpha': 1.0, 'tau': 160, 'w_pf': 0.12}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:51,117] Trial 57 finished with value: 10.40965753092181 and parameters: {'alpha': 1.0, 'tau': 155, 'w_pf': 0.12}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:51,178] Trial 58 finished with value: 10.416025150078093 and parameters: {'alpha': 1.0, 'tau': 160, 'w_pf': 0.13}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:51,201] Trial 59 finished with value: 10.415561435297708 and parameters: {'alpha': 1.0, 'tau': 155, 'w_pf': 0.13}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:51,295] Trial 60 finished with value: 10.426600500611796 and parameters: {'alpha': 0.99, 'tau': 160, 'w_pf': 0.13}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:51,385] Trial 61 finished with value: 10.427113325865273 and parameters: {'alpha': 0.99, 'tau': 165, 'w_pf': 0.13}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:51,472] Trial 62 finished with value: 10.426856571992037 and parameters: {'alpha': 1.0, 'tau': 240, 'w_pf': 0.13}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:51,493] Trial 63 finished with value: 10.407028866863138 and parameters: {'alpha': 1.0, 'tau': 245, 'w_pf': 0.06}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:51,566] Trial 64 finished with value: 10.406167297997007 and parameters: {'alpha': 1.0, 'tau': 240, 'w_pf': 0.06}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:51,639] Trial 65 finished with value: 10.413451660217284 and parameters: {'alpha': 1.0, 'tau': 225, 'w_pf': 0.11}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:51,759] Trial 66 finished with value: 10.458452071958872 and parameters: {'alpha': 0.95, 'tau': 150, 'w_pf': 0.07}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:51,778] Trial 67 finished with value: 10.471747204789997 and parameters: {'alpha': 0.95, 'tau': 240, 'w_pf': 0.06}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:51,849] Trial 68 finished with value: 10.470759311248978 and parameters: {'alpha': 0.95, 'tau': 235, 'w_pf': 0.06}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:51,894] Trial 69 finished with value: 10.473191365166484 and parameters: {'alpha': 0.95, 'tau': 245, 'w_pf': 0.07}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:52,049] Trial 70 finished with value: 10.462356996777691 and parameters: {'alpha': 0.95, 'tau': 185, 'w_pf': 0.06}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:52,069] Trial 71 finished with value: 10.475622143792977 and parameters: {'alpha': 0.95, 'tau': 250, 'w_pf': 0.04}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:52,164] Trial 72 finished with value: 10.44428724347834 and parameters: {'alpha': 0.97, 'tau': 190, 'w_pf': 0.11}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:52,174] Trial 73 finished with value: 10.443600118653269 and parameters: {'alpha': 0.97, 'tau': 185, 'w_pf': 0.11}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:52,335] Trial 74 finished with value: 10.448967591915086 and parameters: {'alpha': 0.97, 'tau': 220, 'w_pf': 0.11}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:52,356] Trial 75 finished with value: 10.448967591915086 and parameters: {'alpha': 0.97, 'tau': 220, 'w_pf': 0.11}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:52,460] Trial 77 finished with value: 10.438413342102999 and parameters: {'alpha': 1.0, 'tau': 220, 'w_pf': 0.15}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:52,464] Trial 76 finished with value: 10.439207356483841 and parameters: {'alpha': 1.0, 'tau': 225, 'w_pf': 0.15}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:52,629] Trial 78 finished with value: 10.446441884665544 and parameters: {'alpha': 1.0, 'tau': 265, 'w_pf': 0.15}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:52,654] Trial 79 finished with value: 10.445452865786327 and parameters: {'alpha': 1.0, 'tau': 260, 'w_pf': 0.15}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:52,768] Trial 81 finished with value: 10.435274844958611 and parameters: {'alpha': 0.98, 'tau': 260, 'w_pf': 0.04}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:52,772] Trial 80 finished with value: 10.435274844958611 and parameters: {'alpha': 0.98, 'tau': 260, 'w_pf': 0.04}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:52,917] Trial 82 finished with value: 10.440588196256682 and parameters: {'alpha': 0.98, 'tau': 285, 'w_pf': 0.04}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:52,941] Trial 83 finished with value: 10.455886926890967 and parameters: {'alpha': 0.98, 'tau': 280, 'w_pf': 0.0}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:53,070] Trial 85 finished with value: 10.518793585917981 and parameters: {'alpha': 0.9299999999999999, 'tau': 285, 'w_pf': 0.08}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:53,078] Trial 84 finished with value: 10.517507505433953 and parameters: {'alpha': 0.9299999999999999, 'tau': 280, 'w_pf': 0.08}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:53,200] Trial 86 finished with value: 10.441705249387827 and parameters: {'alpha': 0.96, 'tau': 115, 'w_pf': 0.08}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:53,210] Trial 87 finished with value: 10.495234181955675 and parameters: {'alpha': 0.9299999999999999, 'tau': 145, 'w_pf': 0.09}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:53,356] Trial 88 finished with value: 10.443788242424764 and parameters: {'alpha': 0.96, 'tau': 115, 'w_pf': 0.09}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:53,364] Trial 89 finished with value: 10.447126878346905 and parameters: {'alpha': 0.96, 'tau': 120, 'w_pf': 0.1}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:53,487] Trial 90 finished with value: 10.407619220708318 and parameters: {'alpha': 0.99, 'tau': 145, 'w_pf': 0.09}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:53,500] Trial 91 finished with value: 10.407624482709627 and parameters: {'alpha': 0.99, 'tau': 95, 'w_pf': 0.1}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:53,635] Trial 93 finished with value: 10.428716978013854 and parameters: {'alpha': 0.99, 'tau': 85, 'w_pf': 0.14}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:53,644] Trial 92 finished with value: 10.407462974398461 and parameters: {'alpha': 0.99, 'tau': 90, 'w_pf': 0.1}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:53,754] Trial 94 finished with value: 10.490492225781594 and parameters: {'alpha': 0.99, 'tau': 95, 'w_pf': 0.2}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:53,776] Trial 95 finished with value: 10.407462974398461 and parameters: {'alpha': 0.99, 'tau': 90, 'w_pf': 0.1}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:53,909] Trial 97 finished with value: 10.409763662064202 and parameters: {'alpha': 0.99, 'tau': 135, 'w_pf': 0.1}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:53,927] Trial 96 finished with value: 10.409763662064202 and parameters: {'alpha': 0.99, 'tau': 135, 'w_pf': 0.1}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:54,037] Trial 99 finished with value: 10.53580747059124 and parameters: {'alpha': 0.91, 'tau': 135, 'w_pf': 0.1}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:54,046] Trial 98 finished with value: 10.53580747059124 and parameters: {'alpha': 0.91, 'tau': 135, 'w_pf': 0.1}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:54,197] Trial 100 finished with value: 10.412548976060537 and parameters: {'alpha': 0.98, 'tau': 60, 'w_pf': 0.07}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:54,233] Trial 101 finished with value: 10.52436851727564 and parameters: {'alpha': 0.91, 'tau': 55, 'w_pf': 0.07}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:54,372] Trial 103 finished with value: 10.412821553400164 and parameters: {'alpha': 0.98, 'tau': 80, 'w_pf': 0.07}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:54,388] Trial 102 finished with value: 10.422169966428553 and parameters: {'alpha': 0.98, 'tau': 55, 'w_pf': 0.02}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:54,485] Trial 104 finished with value: 10.447188132517912 and parameters: {'alpha': 0.96, 'tau': 80, 'w_pf': 0.02}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:54,516] Trial 105 finished with value: 10.439497699772193 and parameters: {'alpha': 0.96, 'tau': 80, 'w_pf': 0.05}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:54,642] Trial 107 finished with value: 10.469572804526642 and parameters: {'alpha': 0.94, 'tau': 30, 'w_pf': 0.05}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:54,649] Trial 106 finished with value: 10.440209200788837 and parameters: {'alpha': 0.96, 'tau': 100, 'w_pf': 0.05}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:54,745] Trial 108 finished with value: 10.40339234827216 and parameters: {'alpha': 0.99, 'tau': 105, 'w_pf': 0.05}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:54,773] Trial 109 finished with value: 10.416554955651502 and parameters: {'alpha': 0.99, 'tau': 100, 'w_pf': 0.12}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:54,914] Trial 110 finished with value: 10.416554955651502 and parameters: {'alpha': 0.99, 'tau': 100, 'w_pf': 0.12}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:54,948] Trial 111 finished with value: 10.458063059407795 and parameters: {'alpha': 0.99, 'tau': 140, 'w_pf': 0.17}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:55,007] Trial 112 finished with value: 10.40511797227343 and parameters: {'alpha': 0.99, 'tau': 105, 'w_pf': 0.09}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:55,038] Trial 113 finished with value: 10.474681891945119 and parameters: {'alpha': 0.94, 'tau': 105, 'w_pf': 0.03}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:55,208] Trial 114 finished with value: 10.410546238879169 and parameters: {'alpha': 0.99, 'tau': 175, 'w_pf': 0.09}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:55,220] Trial 115 finished with value: 10.462716810221506 and parameters: {'alpha': 0.97, 'tau': 315, 'w_pf': 0.09}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:55,264] Trial 116 finished with value: 10.428174835559634 and parameters: {'alpha': 0.97, 'tau': 70, 'w_pf': 0.09}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:55,287] Trial 117 finished with value: 10.430526394390544 and parameters: {'alpha': 0.97, 'tau': 125, 'w_pf': 0.09}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:55,547] Trial 119 finished with value: 10.424936387808282 and parameters: {'alpha': 0.97, 'tau': 65, 'w_pf': 0.06}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:55,550] Trial 118 finished with value: 10.692007803643339 and parameters: {'alpha': 0.8400000000000001, 'tau': 70, 'w_pf': 0.06}. Best is trial 26 with value: 10.392659925839371.
# [I 2026-05-19 00:21:55,574] Trial 121 finished with value: 10.39179162377039 and parameters: {'alpha': 1.0, 'tau': 90, 'w_pf': 0.06}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:55,577] Trial 120 finished with value: 10.696569464918914 and parameters: {'alpha': 0.8400000000000001, 'tau': 130, 'w_pf': 0.06}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:55,867] Trial 123 finished with value: 10.397147579668381 and parameters: {'alpha': 1.0, 'tau': 90, 'w_pf': 0.1}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:55,883] Trial 125 finished with value: 10.392453080291542 and parameters: {'alpha': 1.0, 'tau': 90, 'w_pf': 0.08}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:55,890] Trial 122 finished with value: 10.392145077877093 and parameters: {'alpha': 1.0, 'tau': 40, 'w_pf': 0.08}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:55,897] Trial 124 finished with value: 10.392453080291542 and parameters: {'alpha': 1.0, 'tau': 90, 'w_pf': 0.08}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:56,183] Trial 126 finished with value: 10.392453080291542 and parameters: {'alpha': 1.0, 'tau': 90, 'w_pf': 0.08}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:56,214] Trial 128 finished with value: 10.398205758720833 and parameters: {'alpha': 1.0, 'tau': 40, 'w_pf': 0.03}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:56,228] Trial 129 finished with value: 10.398205758720833 and parameters: {'alpha': 1.0, 'tau': 40, 'w_pf': 0.03}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:56,240] Trial 127 finished with value: 10.398205758720833 and parameters: {'alpha': 1.0, 'tau': 40, 'w_pf': 0.03}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:56,442] Trial 130 finished with value: 10.392207687537027 and parameters: {'alpha': 1.0, 'tau': 35, 'w_pf': 0.08}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:56,544] Trial 131 finished with value: 10.41421824755856 and parameters: {'alpha': 1.0, 'tau': 25, 'w_pf': 0.0}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:56,551] Trial 132 finished with value: 10.398903319044305 and parameters: {'alpha': 1.0, 'tau': 5, 'w_pf': 0.03}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:56,556] Trial 133 finished with value: 11.02462787942308 and parameters: {'alpha': 0.74, 'tau': 40, 'w_pf': 0.0}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:56,704] Trial 134 finished with value: 10.41393406497658 and parameters: {'alpha': 1.0, 'tau': 40, 'w_pf': 0.0}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:56,840] Trial 135 finished with value: 10.418398120004456 and parameters: {'alpha': 0.98, 'tau': 40, 'w_pf': 0.03}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:56,865] Trial 136 finished with value: 10.418924133136738 and parameters: {'alpha': 0.98, 'tau': 10, 'w_pf': 0.03}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:56,866] Trial 137 finished with value: 10.427545385854325 and parameters: {'alpha': 0.98, 'tau': 15, 'w_pf': 0.01}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:56,991] Trial 138 finished with value: 10.427764058609757 and parameters: {'alpha': 0.98, 'tau': 5, 'w_pf': 0.01}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:57,150] Trial 141 finished with value: 10.395331569538897 and parameters: {'alpha': 1.0, 'tau': 20, 'w_pf': 0.04}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:57,163] Trial 140 finished with value: 10.39846632825586 and parameters: {'alpha': 1.0, 'tau': 25, 'w_pf': 0.03}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:57,197] Trial 139 finished with value: 10.419029286374478 and parameters: {'alpha': 0.98, 'tau': 5, 'w_pf': 0.03}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:57,241] Trial 142 finished with value: 10.395331569538897 and parameters: {'alpha': 1.0, 'tau': 20, 'w_pf': 0.04}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:57,450] Trial 143 finished with value: 10.395228866713587 and parameters: {'alpha': 1.0, 'tau': 25, 'w_pf': 0.04}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:57,495] Trial 146 finished with value: 10.395228866713587 and parameters: {'alpha': 1.0, 'tau': 25, 'w_pf': 0.04}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:57,499] Trial 145 finished with value: 10.395331569538897 and parameters: {'alpha': 1.0, 'tau': 20, 'w_pf': 0.04}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:57,501] Trial 144 finished with value: 10.39846632825586 and parameters: {'alpha': 1.0, 'tau': 25, 'w_pf': 0.03}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:57,709] Trial 147 finished with value: 10.395228866713587 and parameters: {'alpha': 1.0, 'tau': 25, 'w_pf': 0.04}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:57,796] Trial 148 finished with value: 10.427500739944536 and parameters: {'alpha': 0.97, 'tau': 50, 'w_pf': 0.04}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:57,839] Trial 150 finished with value: 10.427500739944536 and parameters: {'alpha': 0.97, 'tau': 50, 'w_pf': 0.04}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:57,844] Trial 149 finished with value: 12.208030365555706 and parameters: {'alpha': 0.5, 'tau': 50, 'w_pf': 0.04}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:57,962] Trial 151 finished with value: 10.426036263030248 and parameters: {'alpha': 0.97, 'tau': 20, 'w_pf': 0.05}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:58,048] Trial 152 finished with value: 12.213001985012983 and parameters: {'alpha': 0.5, 'tau': 20, 'w_pf': 0.07}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:58,113] Trial 153 finished with value: 10.438844408068052 and parameters: {'alpha': 0.96, 'tau': 20, 'w_pf': 0.07}. Best is trial 121 with value: 10.39179162377039.
# [I 2026-05-19 00:21:58,137] Trial 154 finished with value: 10.391664769535412 and parameters: {'alpha': 1.0, 'tau': 20, 'w_pf': 0.07}. Best is trial 154 with value: 10.391664769535412.
# [I 2026-05-19 00:21:58,233] Trial 155 finished with value: 10.392207687537027 and parameters: {'alpha': 1.0, 'tau': 35, 'w_pf': 0.08}. Best is trial 154 with value: 10.391664769535412.
# [I 2026-05-19 00:21:58,310] Trial 156 finished with value: 10.392207687537027 and parameters: {'alpha': 1.0, 'tau': 35, 'w_pf': 0.08}. Best is trial 154 with value: 10.391664769535412.
# [I 2026-05-19 00:21:58,373] Trial 157 finished with value: 10.392207687537027 and parameters: {'alpha': 1.0, 'tau': 35, 'w_pf': 0.08}. Best is trial 154 with value: 10.391664769535412.
# [I 2026-05-19 00:21:58,383] Trial 158 finished with value: 10.392282686233717 and parameters: {'alpha': 1.0, 'tau': 30, 'w_pf': 0.08}. Best is trial 154 with value: 10.391664769535412.
# [I 2026-05-19 00:21:58,490] Trial 159 finished with value: 10.41270541800124 and parameters: {'alpha': 0.98, 'tau': 30, 'w_pf': 0.07}. Best is trial 154 with value: 10.391664769535412.
# [I 2026-05-19 00:21:58,553] Trial 160 finished with value: 10.413603276626715 and parameters: {'alpha': 0.98, 'tau': 35, 'w_pf': 0.08}. Best is trial 154 with value: 10.391664769535412.
# [I 2026-05-19 00:21:58,644] Trial 161 finished with value: 10.413666417627107 and parameters: {'alpha': 0.98, 'tau': 30, 'w_pf': 0.08}. Best is trial 154 with value: 10.391664769535412.
# [I 2026-05-19 00:21:58,656] Trial 162 finished with value: 10.413666417627107 and parameters: {'alpha': 0.98, 'tau': 30, 'w_pf': 0.08}. Best is trial 154 with value: 10.391664769535412.
# [I 2026-05-19 00:21:58,725] Trial 163 finished with value: 10.413603276626715 and parameters: {'alpha': 0.98, 'tau': 35, 'w_pf': 0.08}. Best is trial 154 with value: 10.391664769535412.
# [I 2026-05-19 00:21:58,801] Trial 164 finished with value: 10.402377381403948 and parameters: {'alpha': 0.99, 'tau': 30, 'w_pf': 0.08}. Best is trial 154 with value: 10.391664769535412.
# [I 2026-05-19 00:21:58,920] Trial 165 finished with value: 10.402189219064748 and parameters: {'alpha': 0.99, 'tau': 60, 'w_pf': 0.08}. Best is trial 154 with value: 10.391664769535412.
# [I 2026-05-19 00:21:58,931] Trial 166 finished with value: 10.40264085784183 and parameters: {'alpha': 0.99, 'tau': 15, 'w_pf': 0.08}. Best is trial 154 with value: 10.391664769535412.
# [I 2026-05-19 00:21:58,974] Trial 167 finished with value: 10.567307436067749 and parameters: {'alpha': 0.99, 'tau': 60, 'w_pf': 0.25}. Best is trial 154 with value: 10.391664769535412.
# [I 2026-05-19 00:21:59,060] Trial 168 finished with value: 10.391422348624054 and parameters: {'alpha': 1.0, 'tau': 60, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:21:59,219] Trial 169 finished with value: 10.391980564757196 and parameters: {'alpha': 1.0, 'tau': 15, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:21:59,256] Trial 170 finished with value: 10.391449739373309 and parameters: {'alpha': 1.0, 'tau': 50, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:21:59,276] Trial 171 finished with value: 10.392085329221338 and parameters: {'alpha': 1.0, 'tau': 10, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:21:59,303] Trial 172 finished with value: 10.391449739373309 and parameters: {'alpha': 1.0, 'tau': 50, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:21:59,469] Trial 173 finished with value: 10.438385787581336 and parameters: {'alpha': 0.96, 'tau': 50, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:21:59,561] Trial 175 finished with value: 10.391449739373309 and parameters: {'alpha': 1.0, 'tau': 50, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:21:59,580] Trial 174 finished with value: 10.391488301732688 and parameters: {'alpha': 1.0, 'tau': 45, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:21:59,589] Trial 176 finished with value: 10.40139060519268 and parameters: {'alpha': 0.99, 'tau': 50, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:21:59,718] Trial 177 finished with value: 10.401449332880535 and parameters: {'alpha': 0.99, 'tau': 70, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:21:59,826] Trial 178 finished with value: 10.401449332880535 and parameters: {'alpha': 0.99, 'tau': 70, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:21:59,860] Trial 180 finished with value: 10.401364439317264 and parameters: {'alpha': 0.99, 'tau': 70, 'w_pf': 0.07}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:21:59,877] Trial 179 finished with value: 10.40143071612829 and parameters: {'alpha': 0.99, 'tau': 75, 'w_pf': 0.07}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:21:59,965] Trial 181 finished with value: 10.42520348440497 and parameters: {'alpha': 0.97, 'tau': 75, 'w_pf': 0.07}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:00,102] Trial 182 finished with value: 10.424974618026972 and parameters: {'alpha': 0.97, 'tau': 45, 'w_pf': 0.07}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:00,145] Trial 183 finished with value: 11.319552064353763 and parameters: {'alpha': 0.67, 'tau': 60, 'w_pf': 0.07}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:00,160] Trial 184 finished with value: 10.392656850571795 and parameters: {'alpha': 1.0, 'tau': 50, 'w_pf': 0.05}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:00,208] Trial 185 finished with value: 10.392698141455563 and parameters: {'alpha': 1.0, 'tau': 45, 'w_pf': 0.05}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:00,354] Trial 186 finished with value: 10.392623748592358 and parameters: {'alpha': 1.0, 'tau': 60, 'w_pf': 0.05}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:00,427] Trial 187 finished with value: 10.393312248241912 and parameters: {'alpha': 1.0, 'tau': 10, 'w_pf': 0.05}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:00,470] Trial 188 finished with value: 10.392698141455563 and parameters: {'alpha': 1.0, 'tau': 45, 'w_pf': 0.05}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:00,477] Trial 189 finished with value: 10.392623748592358 and parameters: {'alpha': 1.0, 'tau': 60, 'w_pf': 0.05}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:00,607] Trial 190 finished with value: 10.415445078861671 and parameters: {'alpha': 0.98, 'tau': 55, 'w_pf': 0.09}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:00,674] Trial 191 finished with value: 10.415467752260977 and parameters: {'alpha': 0.98, 'tau': 60, 'w_pf': 0.09}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:00,752] Trial 193 finished with value: 10.415890322152736 and parameters: {'alpha': 0.98, 'tau': 85, 'w_pf': 0.09}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:00,761] Trial 192 finished with value: 10.415467752260977 and parameters: {'alpha': 0.98, 'tau': 60, 'w_pf': 0.09}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:00,883] Trial 194 finished with value: 10.4125402381871 and parameters: {'alpha': 0.98, 'tau': 60, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:00,928] Trial 195 finished with value: 10.39167954807291 and parameters: {'alpha': 1.0, 'tau': 85, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:01,029] Trial 196 finished with value: 10.391609711045545 and parameters: {'alpha': 1.0, 'tau': 35, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:01,030] Trial 197 finished with value: 11.50516828302763 and parameters: {'alpha': 0.63, 'tau': 35, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:01,132] Trial 198 finished with value: 10.391609711045545 and parameters: {'alpha': 1.0, 'tau': 35, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:01,194] Trial 199 finished with value: 10.391609711045545 and parameters: {'alpha': 1.0, 'tau': 35, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:01,302] Trial 201 finished with value: 10.402252515056214 and parameters: {'alpha': 0.99, 'tau': 40, 'w_pf': 0.08}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:01,346] Trial 200 finished with value: 10.40283543429986 and parameters: {'alpha': 0.99, 'tau': 5, 'w_pf': 0.08}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:01,386] Trial 202 finished with value: 10.40142381145218 and parameters: {'alpha': 0.99, 'tau': 35, 'w_pf': 0.07}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:01,466] Trial 203 finished with value: 10.4020817614323 and parameters: {'alpha': 0.99, 'tau': 5, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:01,594] Trial 205 finished with value: 10.391609711045545 and parameters: {'alpha': 1.0, 'tau': 35, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:01,618] Trial 204 finished with value: 10.401964353899777 and parameters: {'alpha': 0.99, 'tau': 5, 'w_pf': 0.07}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:01,645] Trial 206 finished with value: 10.391980564757196 and parameters: {'alpha': 1.0, 'tau': 15, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:01,699] Trial 207 finished with value: 10.391609711045545 and parameters: {'alpha': 1.0, 'tau': 35, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:01,900] Trial 208 finished with value: 10.39154206155066 and parameters: {'alpha': 1.0, 'tau': 40, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:01,951] Trial 209 finished with value: 10.391609711045545 and parameters: {'alpha': 1.0, 'tau': 35, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:01,952] Trial 210 finished with value: 10.391980564757196 and parameters: {'alpha': 1.0, 'tau': 15, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:01,976] Trial 211 finished with value: 10.424907703217821 and parameters: {'alpha': 0.97, 'tau': 40, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:02,147] Trial 212 finished with value: 10.42526756196332 and parameters: {'alpha': 0.97, 'tau': 15, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:02,263] Trial 215 finished with value: 10.391877729202552 and parameters: {'alpha': 1.0, 'tau': 20, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:02,269] Trial 214 finished with value: 10.391980564757196 and parameters: {'alpha': 1.0, 'tau': 15, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:02,280] Trial 213 finished with value: 10.391980564757196 and parameters: {'alpha': 1.0, 'tau': 15, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:02,409] Trial 216 finished with value: 10.393205254085428 and parameters: {'alpha': 1.0, 'tau': 15, 'w_pf': 0.05}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:02,569] Trial 219 finished with value: 10.413956391559724 and parameters: {'alpha': 0.98, 'tau': 15, 'w_pf': 0.05}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:02,597] Trial 217 finished with value: 10.402980239525828 and parameters: {'alpha': 0.99, 'tau': 15, 'w_pf': 0.05}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:02,602] Trial 218 finished with value: 10.402980239525828 and parameters: {'alpha': 0.99, 'tau': 15, 'w_pf': 0.05}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:02,650] Trial 220 finished with value: 10.412975616060804 and parameters: {'alpha': 0.98, 'tau': 15, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:02,856] Trial 221 finished with value: 10.401878674255547 and parameters: {'alpha': 0.99, 'tau': 15, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:02,898] Trial 222 finished with value: 10.412791513828466 and parameters: {'alpha': 0.98, 'tau': 25, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:02,935] Trial 224 finished with value: 10.391779794409937 and parameters: {'alpha': 1.0, 'tau': 25, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:02,937] Trial 223 finished with value: 10.412880393866697 and parameters: {'alpha': 0.98, 'tau': 20, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:03,102] Trial 225 finished with value: 10.391779794409937 and parameters: {'alpha': 1.0, 'tau': 25, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:03,180] Trial 226 finished with value: 10.391488301732688 and parameters: {'alpha': 1.0, 'tau': 45, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:03,222] Trial 227 finished with value: 10.39299980579399 and parameters: {'alpha': 1.0, 'tau': 25, 'w_pf': 0.05}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:03,224] Trial 228 finished with value: 10.395133796464497 and parameters: {'alpha': 1.0, 'tau': 30, 'w_pf': 0.04}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:03,361] Trial 229 finished with value: 10.392698141455563 and parameters: {'alpha': 1.0, 'tau': 45, 'w_pf': 0.05}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:03,437] Trial 230 finished with value: 10.404582720419041 and parameters: {'alpha': 0.99, 'tau': 45, 'w_pf': 0.04}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:03,498] Trial 232 finished with value: 10.401321955050204 and parameters: {'alpha': 0.99, 'tau': 45, 'w_pf': 0.07}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:03,506] Trial 231 finished with value: 10.401294454672696 and parameters: {'alpha': 0.99, 'tau': 50, 'w_pf': 0.07}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:03,619] Trial 233 finished with value: 10.401294454672696 and parameters: {'alpha': 0.99, 'tau': 50, 'w_pf': 0.07}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:03,675] Trial 234 finished with value: 10.401495218889536 and parameters: {'alpha': 0.99, 'tau': 30, 'w_pf': 0.07}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:03,765] Trial 236 finished with value: 10.39168962928854 and parameters: {'alpha': 1.0, 'tau': 30, 'w_pf': 0.06}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:03,792] Trial 235 finished with value: 10.391569187960652 and parameters: {'alpha': 1.0, 'tau': 25, 'w_pf': 0.07}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:03,873] Trial 237 finished with value: 10.39299980579399 and parameters: {'alpha': 1.0, 'tau': 25, 'w_pf': 0.05}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:03,928] Trial 238 finished with value: 10.39290720045034 and parameters: {'alpha': 1.0, 'tau': 30, 'w_pf': 0.05}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:04,041] Trial 239 finished with value: 10.39290720045034 and parameters: {'alpha': 1.0, 'tau': 30, 'w_pf': 0.05}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:04,059] Trial 240 finished with value: 10.39290720045034 and parameters: {'alpha': 1.0, 'tau': 30, 'w_pf': 0.05}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:04,116] Trial 241 finished with value: 10.4136155952375 and parameters: {'alpha': 0.98, 'tau': 35, 'w_pf': 0.05}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:04,222] Trial 242 finished with value: 10.973075249509693 and parameters: {'alpha': 0.98, 'tau': 35, 'w_pf': 0.41000000000000003}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:04,349] Trial 243 finished with value: 10.412588320656653 and parameters: {'alpha': 0.98, 'tau': 40, 'w_pf': 0.07}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:04,357] Trial 244 finished with value: 11.005163850797432 and parameters: {'alpha': 0.98, 'tau': 40, 'w_pf': 0.42}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:04,414] Trial 245 finished with value: 10.401365513003356 and parameters: {'alpha': 0.99, 'tau': 40, 'w_pf': 0.07}. Best is trial 168 with value: 10.391422348624054.
# [I 2026-05-19 00:22:04,488] Trial 246 finished with value: 10.391287730463587 and parameters: {'alpha': 1.0, 'tau': 45, 'w_pf': 0.07}. Best is trial 246 with value: 10.391287730463587.
# [I 2026-05-19 00:22:04,633] Trial 248 finished with value: 10.391449739373309 and parameters: {'alpha': 1.0, 'tau': 50, 'w_pf': 0.06}. Best is trial 246 with value: 10.391287730463587.
# [I 2026-05-19 00:22:04,675] Trial 247 finished with value: 10.392189404252223 and parameters: {'alpha': 1.0, 'tau': 5, 'w_pf': 0.06}. Best is trial 246 with value: 10.391287730463587.
# [I 2026-05-19 00:22:04,715] Trial 249 finished with value: 10.392189404252223 and parameters: {'alpha': 1.0, 'tau': 5, 'w_pf': 0.06}. Best is trial 246 with value: 10.391287730463587.
# [I 2026-05-19 00:22:04,737] Trial 250 finished with value: 10.391449739373309 and parameters: {'alpha': 1.0, 'tau': 50, 'w_pf': 0.06}. Best is trial 246 with value: 10.391287730463587.
# [I 2026-05-19 00:22:04,891] Trial 251 finished with value: 10.401284096018205 and parameters: {'alpha': 0.99, 'tau': 55, 'w_pf': 0.07}. Best is trial 246 with value: 10.391287730463587.
# [I 2026-05-19 00:22:04,950] Trial 252 finished with value: 10.401284096018205 and parameters: {'alpha': 0.99, 'tau': 55, 'w_pf': 0.07}. Best is trial 246 with value: 10.391287730463587.
# [I 2026-05-19 00:22:04,995] Trial 253 finished with value: 11.14566515826791 and parameters: {'alpha': 0.71, 'tau': 50, 'w_pf': 0.07}. Best is trial 246 with value: 10.391287730463587.
# [I 2026-05-19 00:22:05,010] Trial 254 finished with value: 10.401284096018205 and parameters: {'alpha': 0.99, 'tau': 55, 'w_pf': 0.07}. Best is trial 246 with value: 10.391287730463587.
# [I 2026-05-19 00:22:05,144] Trial 255 finished with value: 10.404547205591099 and parameters: {'alpha': 0.99, 'tau': 50, 'w_pf': 0.04}. Best is trial 246 with value: 10.391287730463587.
# [I 2026-05-19 00:22:05,206] Trial 256 finished with value: 10.404547205591099 and parameters: {'alpha': 0.99, 'tau': 50, 'w_pf': 0.04}. Best is trial 246 with value: 10.391287730463587.
# [I 2026-05-19 00:22:05,268] Trial 258 finished with value: 10.404545540520823 and parameters: {'alpha': 0.99, 'tau': 65, 'w_pf': 0.04}. Best is trial 246 with value: 10.391287730463587.
# ...
# [I 2026-05-19 00:22:17,153] Trial 414 finished with value: 11.063304695721756 and parameters: {'alpha': 0.73, 'tau': 60, 'w_pf': 0.06}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:17,247] Trial 415 finished with value: 10.39154206155066 and parameters: {'alpha': 1.0, 'tau': 40, 'w_pf': 0.06}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:17,409] Trial 416 finished with value: 10.39154206155066 and parameters: {'alpha': 1.0, 'tau': 40, 'w_pf': 0.06}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:17,471] Trial 417 finished with value: 11.60474705745591 and parameters: {'alpha': 0.61, 'tau': 40, 'w_pf': 0.06}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:17,485] Trial 418 finished with value: 10.392145077877093 and parameters: {'alpha': 1.0, 'tau': 40, 'w_pf': 0.08}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:17,513] Trial 419 finished with value: 11.60317027221256 and parameters: {'alpha': 0.61, 'tau': 45, 'w_pf': 0.05}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:17,671] Trial 420 finished with value: 10.692064337659625 and parameters: {'alpha': 0.8400000000000001, 'tau': 45, 'w_pf': 0.03}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:17,788] Trial 421 finished with value: 10.407645041100759 and parameters: {'alpha': 0.99, 'tau': 45, 'w_pf': 0.03}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:17,792] Trial 423 finished with value: 10.413624848900593 and parameters: {'alpha': 0.98, 'tau': 70, 'w_pf': 0.08}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:17,810] Trial 422 finished with value: 10.418351763959768 and parameters: {'alpha': 0.98, 'tau': 45, 'w_pf': 0.03}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:17,931] Trial 424 finished with value: 10.413685849694504 and parameters: {'alpha': 0.98, 'tau': 30, 'w_pf': 0.05}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:18,101] Trial 425 finished with value: 10.413685849694504 and parameters: {'alpha': 0.98, 'tau': 30, 'w_pf': 0.05}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:18,141] Trial 427 finished with value: 10.39290720045034 and parameters: {'alpha': 1.0, 'tau': 30, 'w_pf': 0.05}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:18,143] Trial 426 finished with value: 10.413486741215673 and parameters: {'alpha': 0.98, 'tau': 55, 'w_pf': 0.05}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:18,178] Trial 428 finished with value: 10.391427451439618 and parameters: {'alpha': 1.0, 'tau': 55, 'w_pf': 0.06}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:18,355] Trial 429 finished with value: 10.391449739373309 and parameters: {'alpha': 1.0, 'tau': 50, 'w_pf': 0.06}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:18,450] Trial 432 finished with value: 10.404158245300968 and parameters: {'alpha': 0.99, 'tau': 70, 'w_pf': 0.09}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:18,480] Trial 430 finished with value: 10.39204639064959 and parameters: {'alpha': 1.0, 'tau': 55, 'w_pf': 0.08}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:18,488] Trial 431 finished with value: 10.39204639064959 and parameters: {'alpha': 1.0, 'tau': 55, 'w_pf': 0.08}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:18,617] Trial 433 finished with value: 10.404158245300968 and parameters: {'alpha': 0.99, 'tau': 70, 'w_pf': 0.09}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:18,753] Trial 434 finished with value: 10.444821367072434 and parameters: {'alpha': 0.99, 'tau': 55, 'w_pf': 0.16}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:18,798] Trial 436 finished with value: 10.401364439317264 and parameters: {'alpha': 0.99, 'tau': 70, 'w_pf': 0.07}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:18,800] Trial 435 finished with value: 10.401284096018205 and parameters: {'alpha': 0.99, 'tau': 55, 'w_pf': 0.07}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:18,870] Trial 437 finished with value: 10.401284096018205 and parameters: {'alpha': 0.99, 'tau': 55, 'w_pf': 0.07}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:19,012] Trial 438 finished with value: 10.407606659760146 and parameters: {'alpha': 0.99, 'tau': 175, 'w_pf': 0.07}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:19,103] Trial 439 finished with value: 10.394833893408308 and parameters: {'alpha': 1.0, 'tau': 60, 'w_pf': 0.04}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:19,106] Trial 440 finished with value: 11.920884474017917 and parameters: {'alpha': 0.55, 'tau': 60, 'w_pf': 0.04}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:19,137] Trial 441 finished with value: 10.394840715770249 and parameters: {'alpha': 1.0, 'tau': 65, 'w_pf': 0.04}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:19,277] Trial 442 finished with value: 10.394840715770249 and parameters: {'alpha': 1.0, 'tau': 65, 'w_pf': 0.04}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:19,406] Trial 443 finished with value: 10.425198475907301 and parameters: {'alpha': 0.97, 'tau': 80, 'w_pf': 0.06}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:19,409] Trial 444 finished with value: 10.424876435455051 and parameters: {'alpha': 0.97, 'tau': 45, 'w_pf': 0.06}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:19,437] Trial 445 finished with value: 10.425664315652554 and parameters: {'alpha': 0.97, 'tau': 95, 'w_pf': 0.06}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:19,533] Trial 446 finished with value: 10.425664315652554 and parameters: {'alpha': 0.97, 'tau': 95, 'w_pf': 0.06}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:19,718] Trial 447 finished with value: 10.392282686233717 and parameters: {'alpha': 1.0, 'tau': 30, 'w_pf': 0.08}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:19,754] Trial 448 finished with value: 10.392282686233717 and parameters: {'alpha': 1.0, 'tau': 30, 'w_pf': 0.08}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:19,767] Trial 449 finished with value: 10.392282686233717 and parameters: {'alpha': 1.0, 'tau': 30, 'w_pf': 0.08}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:19,772] Trial 450 finished with value: 10.392282686233717 and parameters: {'alpha': 1.0, 'tau': 30, 'w_pf': 0.08}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:20,048] Trial 451 finished with value: 10.413520392570897 and parameters: {'alpha': 0.98, 'tau': 45, 'w_pf': 0.08}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:20,080] Trial 454 finished with value: 10.413517927848154 and parameters: {'alpha': 0.98, 'tau': 45, 'w_pf': 0.05}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:20,120] Trial 453 finished with value: 10.422225099180805 and parameters: {'alpha': 0.98, 'tau': 45, 'w_pf': 0.11}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:20,121] Trial 452 finished with value: 10.415455674324114 and parameters: {'alpha': 0.98, 'tau': 45, 'w_pf': 0.09}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:20,302] Trial 455 finished with value: 10.41349345590382 and parameters: {'alpha': 0.98, 'tau': 50, 'w_pf': 0.05}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:20,403] Trial 456 finished with value: 10.40139060519268 and parameters: {'alpha': 0.99, 'tau': 50, 'w_pf': 0.06}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:20,414] Trial 457 finished with value: 10.402582307459632 and parameters: {'alpha': 0.99, 'tau': 75, 'w_pf': 0.05}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:20,415] Trial 458 finished with value: 10.402582307459632 and parameters: {'alpha': 0.99, 'tau': 75, 'w_pf': 0.05}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:20,562] Trial 459 finished with value: 10.401878674255547 and parameters: {'alpha': 0.99, 'tau': 15, 'w_pf': 0.06}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:20,699] Trial 460 finished with value: 10.78123657862448 and parameters: {'alpha': 0.81, 'tau': 15, 'w_pf': 0.07}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:20,729] Trial 461 finished with value: 10.391765318171213 and parameters: {'alpha': 1.0, 'tau': 15, 'w_pf': 0.07}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:20,763] Trial 462 finished with value: 10.905188426173996 and parameters: {'alpha': 1.0, 'tau': 20, 'w_pf': 0.39}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:20,815] Trial 463 finished with value: 10.391403994956939 and parameters: {'alpha': 1.0, 'tau': 35, 'w_pf': 0.07}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:20,956] Trial 464 finished with value: 10.391403994956939 and parameters: {'alpha': 1.0, 'tau': 35, 'w_pf': 0.07}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:21,024] Trial 466 finished with value: 10.396784345288317 and parameters: {'alpha': 1.0, 'tau': 40, 'w_pf': 0.1}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:21,045] Trial 465 finished with value: 10.396842068352015 and parameters: {'alpha': 1.0, 'tau': 35, 'w_pf': 0.1}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:21,078] Trial 467 finished with value: 10.393872647240073 and parameters: {'alpha': 1.0, 'tau': 60, 'w_pf': 0.09}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:21,214] Trial 468 finished with value: 10.39402055463554 and parameters: {'alpha': 1.0, 'tau': 35, 'w_pf': 0.09}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:21,348] Trial 469 finished with value: 10.404181030800858 and parameters: {'alpha': 0.99, 'tau': 35, 'w_pf': 0.09}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:21,350] Trial 471 finished with value: 10.412782722678166 and parameters: {'alpha': 0.98, 'tau': 25, 'w_pf': 0.07}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:21,361] Trial 470 finished with value: 10.404325521321034 and parameters: {'alpha': 0.99, 'tau': 25, 'w_pf': 0.09}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:21,478] Trial 472 finished with value: 11.178736589256637 and parameters: {'alpha': 0.99, 'tau': 25, 'w_pf': 0.47000000000000003}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:21,661] Trial 474 finished with value: 10.513691167258816 and parameters: {'alpha': 0.98, 'tau': 55, 'w_pf': 0.21}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:21,681] Trial 473 finished with value: 10.401284096018205 and parameters: {'alpha': 0.99, 'tau': 55, 'w_pf': 0.07}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:21,687] Trial 475 finished with value: 10.43859749242812 and parameters: {'alpha': 0.96, 'tau': 55, 'w_pf': 0.07}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:21,734] Trial 476 finished with value: 10.452076982611837 and parameters: {'alpha': 0.96, 'tau': 215, 'w_pf': 0.07}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:21,978] Trial 477 finished with value: 10.438770204498026 and parameters: {'alpha': 0.96, 'tau': 70, 'w_pf': 0.07}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:22,007] Trial 478 finished with value: 10.391466771623362 and parameters: {'alpha': 1.0, 'tau': 70, 'w_pf': 0.06}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:22,038] Trial 479 finished with value: 10.391466771623362 and parameters: {'alpha': 1.0, 'tau': 70, 'w_pf': 0.06}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:22,054] Trial 480 finished with value: 10.39210298351633 and parameters: {'alpha': 1.0, 'tau': 70, 'w_pf': 0.08}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:22,273] Trial 481 finished with value: 10.39206322870949 and parameters: {'alpha': 1.0, 'tau': 50, 'w_pf': 0.08}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:22,319] Trial 482 finished with value: 10.413061065480157 and parameters: {'alpha': 0.98, 'tau': 90, 'w_pf': 0.06}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:22,345] Trial 483 finished with value: 10.414081037415656 and parameters: {'alpha': 0.98, 'tau': 90, 'w_pf': 0.08}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:22,348] Trial 484 finished with value: 10.415660716904416 and parameters: {'alpha': 0.98, 'tau': 80, 'w_pf': 0.04}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:22,538] Trial 485 finished with value: 10.415660716904416 and parameters: {'alpha': 0.98, 'tau': 80, 'w_pf': 0.04}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:22,611] Trial 486 finished with value: 10.404815441409227 and parameters: {'alpha': 0.99, 'tau': 85, 'w_pf': 0.04}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:22,684] Trial 487 finished with value: 10.402764879903232 and parameters: {'alpha': 0.99, 'tau': 85, 'w_pf': 0.05}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:22,688] Trial 488 finished with value: 10.402764879903232 and parameters: {'alpha': 0.99, 'tau': 85, 'w_pf': 0.05}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:22,790] Trial 489 finished with value: 10.402582307459632 and parameters: {'alpha': 0.99, 'tau': 75, 'w_pf': 0.05}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:22,871] Trial 490 finished with value: 10.401449332880535 and parameters: {'alpha': 0.99, 'tau': 70, 'w_pf': 0.06}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:22,990] Trial 492 finished with value: 10.392680287043179 and parameters: {'alpha': 1.0, 'tau': 115, 'w_pf': 0.06}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:22,998] Trial 491 finished with value: 10.50448719005681 and parameters: {'alpha': 0.9199999999999999, 'tau': 65, 'w_pf': 0.06}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:23,041] Trial 493 finished with value: 10.391435221480377 and parameters: {'alpha': 1.0, 'tau': 65, 'w_pf': 0.06}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:23,116] Trial 494 finished with value: 10.391245831744335 and parameters: {'alpha': 1.0, 'tau': 65, 'w_pf': 0.07}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:23,309] Trial 495 finished with value: 10.391245831744335 and parameters: {'alpha': 1.0, 'tau': 65, 'w_pf': 0.07}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:23,323] Trial 496 finished with value: 10.594964879749995 and parameters: {'alpha': 0.9, 'tau': 340, 'w_pf': 0.07}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:23,327] Trial 497 finished with value: 10.425045042088772 and parameters: {'alpha': 0.97, 'tau': 65, 'w_pf': 0.07}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:23,366] Trial 498 finished with value: 10.641163015155895 and parameters: {'alpha': 0.86, 'tau': 70, 'w_pf': 0.08}. Best is trial 386 with value: 10.391245831744335.
# [I 2026-05-19 00:22:23,493] Trial 499 finished with value: 10.427305823859909 and parameters: {'alpha': 0.97, 'tau': 105, 'w_pf': 0.08}. Best is trial 386 with value: 10.391245831744335.

# %% [markdown]
# # 6. Inference

# %%
test_df2 = test_df.copy()
pf_test = test_df2['pf_ancc'].values - test_df2['last_known_tvt'].values
 
test_df2['pred'] = test_df2['last_known_tvt'].values + apply_pp(
    test_df2,
    hc_test_preds,
    pf_test,
    best_pp_params['alpha'],
    best_pp_params['tau'],
    best_pp_params['w_pf']
)
test_df2 = sg_smooth(test_df2, 'pred')

# %%
sample_sub = pd.read_csv(CFG.dataset_path / "sample_submission.csv")
sub = (sample_sub[['id']].merge(
    test_df2[['id', 'pred']].rename(columns={'pred': 'tvt'}),
    on='id',
    how='left'
))
 
sub['tvt'] = sub['tvt'].fillna(float(train_df['last_known_tvt'].mean() + train_df['target'].mean()))
sub[['id', 'tvt']].to_csv("submission.csv", index=False)
sub
# Out:
#                   id           tvt
# 0      000d7d20_1442  11747.367668
# 1      000d7d20_1443  11747.370628
# 2      000d7d20_1444  11747.373634
# 3      000d7d20_1445  11747.376645
# 4      000d7d20_1446  11747.379621
# ...              ...           ...
# 14146  00e12e8b_6379  11596.695610
# 14147  00e12e8b_6380  11596.690630
# 14148  00e12e8b_6381  11596.679051
# 14149  00e12e8b_6382  11596.659461
# 14150  00e12e8b_6383  11596.630449
#
# [14151 rows x 2 columns]

# %%
import json
import numpy as np
import pandas as pd

sample_check = pd.read_csv(CFG.dataset_path / "sample_submission.csv")
sub_check = pd.read_csv("submission.csv")

validation_report = {
    "submission_shape": list(sub_check.shape),
    "sample_shape": list(sample_check.shape),
    "ids_match_sample_order": sub_check["id"].astype(str).tolist() == sample_check["id"].astype(str).tolist(),
    "finite_tvt": bool(np.isfinite(sub_check["tvt"].to_numpy(dtype=float)).all()),
    "prediction_min": float(sub_check["tvt"].min()),
    "prediction_max": float(sub_check["tvt"].max()),
    "prediction_mean": float(sub_check["tvt"].mean()),
}

assert validation_report["submission_shape"] == validation_report["sample_shape"], validation_report
assert validation_report["ids_match_sample_order"], validation_report
assert validation_report["finite_tvt"], validation_report

print(json.dumps(validation_report, indent=2))
# Out:
# {
#   "submission_shape": [
#     14151,
#     2
#   ],
#   "sample_shape": [
#     14151,
#     2
#   ],
#   "ids_match_sample_order": true,
#   "finite_tvt": true,
#   "prediction_min": 11590.135128369817,
#   "prediction_max": 12237.207180190631,
#   "prediction_mean": 11904.715744314126
# }

# %% [markdown]
# # 7. Results

# %%
fold_scores_df = pd.DataFrame(fold_scores)
overall_scores_df = pd.DataFrame({k: [v] for k, v in overall_scores.items()}).transpose().sort_values(by=0, ascending=True)
order = overall_scores_df.index.tolist()

min_score = overall_scores_df.values.flatten().min()
max_score = overall_scores_df.values.flatten().max()
padding = (max_score - min_score) * 0.5
lower_limit = min_score - padding
upper_limit = max_score + padding

fig, axs = plt.subplots(1, 2, figsize=(15, fold_scores_df.shape[1] * 0.5))

boxplot = sns.boxplot(data=fold_scores_df, order=order, ax=axs[0], orient="h", color="grey")
axs[0].set_title(f"Fold RMSE")
axs[0].set_xlabel("")
axs[0].set_ylabel("")

barplot = sns.barplot(x=overall_scores_df.values.flatten(), y=overall_scores_df.index, ax=axs[1], color="grey")
axs[1].set_title(f"Overall RMSE")
axs[1].set_xlabel("")
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel("")

for i, (score, model) in enumerate(zip(overall_scores_df.values.flatten(), overall_scores_df.index)):
    color = "cyan" if "hill" in model.lower() else "grey"
    barplot.patches[i].set_facecolor(color)
    boxplot.patches[i].set_facecolor(color)
    barplot.text(score, i, round(score, 3), va="center")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## How to improve from here
#
# High-signal next steps:
#
# - try alternate artifact families only after confirming they are fully
#   runnable under your account;
# - keep a pinned best output and compare every candidate against it;
# - prefer one or two staged submissions, wait for scores, then decide the
#   next slot;
# - log blank-score cases separately, because a structurally valid output
#   can still fail to return a public score in this competition.
#
# If this notebook saves you time, please upvote and fork it with your own
# validation report and score notes.
